# %%
# Import libraries
import pandas as pd
import numpy as np
from oandapyV20 import API
from oandapyV20.endpoints.instruments import InstrumentsCandles

# ===== YOUR CREDENTIALS () =====
ACCESS_TOKEN = "32a7ce5d62167ef2dda800802386d48a-496bae9b01506113e0a75dbac8e7a693"  # 

# 1. Function to fetch historical data for one instrument
def fetch_forex_data(instrument="EUR_USD", granularity="M1", count=5000):
    client = API(access_token=ACCESS_TOKEN, environment="practice")

    params = {
        "granularity": granularity,
        "count": count
    }

    r = InstrumentsCandles(instrument=instrument, params=params)

    try:
        client.request(r)
    except Exception as e:
        raise ConnectionError(f"Failed to fetch data for {instrument}: {e}")

    data = []
    for candle in r.response['candles']:
        data.append({
            'datetime': candle['time'],
            'close': float(candle['mid']['c'])
        })

    df = pd.DataFrame(data)
    df['datetime'] = pd.to_datetime(df['datetime'])
    df.set_index('datetime', inplace=True)
    return df[['close']].rename(columns={'close': instrument})

# 2. Define triangles
def get_triangles():
    return [
        ["EUR", "USD", "GBP"],
        ["AUD", "USD", "CAD"],
        ["NZD", "USD", "CHF"],
        ["EUR", "JPY", "USD"]
    ]

# 3. Detect arbitrage opportunity at a single timestamp
def detect_opportunity(triangle, row):
    c1, c2, c3 = triangle
    p1 = f"{c1}_{c2}"
    p2 = f"{c2}_{c3}"
    p3 = f"{c3}_{c1}"

    try:
        # Forward path: c1 -> c2 -> c3 -> c1
        val = 1.0
        val *= row[p1]
        val *= row[p2]
        val *= row[p3]

        profit = val - 1.0
        return profit
    except KeyError:
        return None

# 4. Main backtest function
def run_triangular_arbitrage_backtest(pairs, granularity="H1", count=100):
    dfs = []
    print("📥 Fetching historical data for:")
    for pair in pairs:
        print(f"  - {pair}")
        df = fetch_forex_data(pair, granularity, count)
        dfs.append(df)

    # Merge all into one DataFrame
    merged = pd.concat(dfs, axis=1)
    merged.dropna(inplace=True)
    merged.sort_index(inplace=True)

    print("\n📊 Merged DataFrame Sample:")
    print(merged.head())

    triangles = get_triangles()
    results = []

    print("\n🔍 Running backtest for triangular arbitrage opportunities...\n")
    for idx, row in merged.iterrows():
        found = False
        for triangle in triangles:
            profit = detect_opportunity(triangle, row)
            if profit is not None and profit > 0.0001:
                print(f"✅ Opportunity at {idx} | Triangle: {triangle} | Profit: {profit*100:.4f}%")
                results.append({
                    "timestamp": idx,
                    "triangle": str(triangle),
                    "profit_percent": round(profit * 100, 4)
                })
                found = True
        if not found:
            print(f"❌ No opportunity at {idx}")

    print("\n📈 Summary of Opportunities:")
    result_df = pd.DataFrame(results)
    if not result_df.empty:
        print(result_df.to_string(index=False))
    else:
        print("None found.")
    return result_df

# ===== RUN FULL BACKTEST =====
if __name__ == "__main__":
    # List of forex pairs needed for the triangles
    forex_pairs = [
        "EUR_USD", "GBP_USD", "GBP_CHF",
        "AUD_USD",  "NZD_USD",
        "USD_JPY", "EUR_JPY"
    ]

    # Run the backtest
    arbitrage_results = run_triangular_arbitrage_backtest(
        pairs=forex_pairs,
        granularity="M1",   # You can change to H4, D etc.
        count=5000           # Number of candles to fetch
    )
# Out:
# 📥 Fetching historical data for:
#   - EUR_USD
#   - GBP_USD
#   - GBP_CHF
#   - AUD_USD
#   - NZD_USD
#   - USD_JPY
#   - EUR_JPY
#
# 📊 Merged DataFrame Sample:
#                            EUR_USD  GBP_USD  GBP_CHF  AUD_USD  NZD_USD  \
# datetime
# 2025-06-10 21:53:00+00:00  1.14262  1.35004  1.11096  0.65242  0.60516
# 2025-06-10 21:54:00+00:00  1.14260  1.35006  1.11082  0.65246  0.60516
# 2025-06-10 21:55:00+00:00  1.14254  1.35014  1.11092  0.65240  0.60517
# 2025-06-10 21:56:00+00:00  1.14258  1.35016  1.11091  0.65244  0.60521
# 2025-06-10 21:57:00+00:00  1.14260  1.35018  1.11094  0.65246  0.60521
#
#                            USD_JPY  EUR_JPY
# datetime
# 2025-06-10 21:53:00+00:00  144.874  165.535
# 2025-06-10 21:54:00+00:00  144.875  165.540
# 2025-06-10 21:55:00+00:00  144.868  165.520
# 2025-06-10 21:56:00+00:00  144.868  165.511
# 2025-06-10 21:57:00+00:00  144.873  165.516
#
# 🔍 Running backtest for triangular arbitrage opportunities...
#
# ❌ No opportunity at 2025-06-10 21:53:00+00:00
# ❌ No opportunity at 2025-06-10 21:54:00+00:00
# ❌ No opportunity at 2025-06-10 21:55:00+00:00
# ❌ No opportunity at 2025-06-10 21:56:00+00:00
# ❌ No opportunity at 2025-06-10 21:57:00+00:00
# ❌ No opportunity at 2025-06-10 21:58:00+00:00
# ❌ No opportunity at 2025-06-10 21:59:00+00:00
# ❌ No opportunity at 2025-06-10 22:00:00+00:00
# ❌ No opportunity at 2025-06-10 22:01:00+00:00
# ❌ No opportunity at 2025-06-10 22:02:00+00:00
# ❌ No opportunity at 2025-06-10 22:03:00+00:00
# ❌ No opportunity at 2025-06-10 22:04:00+00:00
# ❌ No opportunity at 2025-06-10 22:05:00+00:00
# ❌ No opportunity at 2025-06-10 22:06:00+00:00
# ❌ No opportunity at 2025-06-10 22:07:00+00:00
# ❌ No opportunity at 2025-06-10 22:09:00+00:00
# ❌ No opportunity at 2025-06-10 22:10:00+00:00
# ❌ No opportunity at 2025-06-10 22:11:00+00:00
# ❌ No opportunity at 2025-06-10 22:12:00+00:00
# ❌ No opportunity at 2025-06-10 22:13:00+00:00
# ❌ No opportunity at 2025-06-10 22:14:00+00:00
# ❌ No opportunity at 2025-06-10 22:15:00+00:00
# ❌ No opportunity at 2025-06-10 22:16:00+00:00
# ❌ No opportunity at 2025-06-10 22:17:00+00:00
# ❌ No opportunity at 2025-06-10 22:18:00+00:00
# ❌ No opportunity at 2025-06-10 22:19:00+00:00
# ❌ No opportunity at 2025-06-10 22:20:00+00:00
# ❌ No opportunity at 2025-06-10 22:22:00+00:00
# ❌ No opportunity at 2025-06-10 22:23:00+00:00
# ❌ No opportunity at 2025-06-10 22:24:00+00:00
# ❌ No opportunity at 2025-06-10 22:26:00+00:00
# ❌ No opportunity at 2025-06-10 22:27:00+00:00
# ❌ No opportunity at 2025-06-10 22:28:00+00:00
# ❌ No opportunity at 2025-06-10 22:29:00+00:00
# ❌ No opportunity at 2025-06-10 22:30:00+00:00
# ❌ No opportunity at 2025-06-10 22:31:00+00:00
# ❌ No opportunity at 2025-06-10 22:32:00+00:00
# ❌ No opportunity at 2025-06-10 22:33:00+00:00
# ❌ No opportunity at 2025-06-10 22:34:00+00:00
# ❌ No opportunity at 2025-06-10 22:35:00+00:00
# ❌ No opportunity at 2025-06-10 22:36:00+00:00
# ❌ No opportunity at 2025-06-10 22:37:00+00:00
# ❌ No opportunity at 2025-06-10 22:38:00+00:00
# ❌ No opportunity at 2025-06-10 22:39:00+00:00
# ❌ No opportunity at 2025-06-10 22:40:00+00:00
# ❌ No opportunity at 2025-06-10 22:41:00+00:00
# ❌ No opportunity at 2025-06-10 22:42:00+00:00
# ❌ No opportunity at 2025-06-10 22:43:00+00:00
# ❌ No opportunity at 2025-06-10 22:44:00+00:00
# ❌ No opportunity at 2025-06-10 22:45:00+00:00
# ❌ No opportunity at 2025-06-10 22:46:00+00:00
# ❌ No opportunity at 2025-06-10 22:47:00+00:00
# ❌ No opportunity at 2025-06-10 22:48:00+00:00
# ❌ No opportunity at 2025-06-10 22:49:00+00:00
# ❌ No opportunity at 2025-06-10 22:50:00+00:00
# ❌ No opportunity at 2025-06-10 22:51:00+00:00
# ❌ No opportunity at 2025-06-10 22:52:00+00:00
# ❌ No opportunity at 2025-06-10 22:53:00+00:00
# ❌ No opportunity at 2025-06-10 22:54:00+00:00
# ❌ No opportunity at 2025-06-10 22:55:00+00:00
# ❌ No opportunity at 2025-06-10 22:56:00+00:00
# ❌ No opportunity at 2025-06-10 22:57:00+00:00
# ❌ No opportunity at 2025-06-10 22:58:00+00:00
# ❌ No opportunity at 2025-06-10 22:59:00+00:00
# ❌ No opportunity at 2025-06-10 23:00:00+00:00
# ❌ No opportunity at 2025-06-10 23:01:00+00:00
# ❌ No opportunity at 2025-06-10 23:02:00+00:00
# ❌ No opportunity at 2025-06-10 23:03:00+00:00
# ❌ No opportunity at 2025-06-10 23:04:00+00:00
# ❌ No opportunity at 2025-06-10 23:05:00+00:00
# ❌ No opportunity at 2025-06-10 23:06:00+00:00
# ❌ No opportunity at 2025-06-10 23:07:00+00:00
# ❌ No opportunity at 2025-06-10 23:08:00+00:00
# ❌ No opportunity at 2025-06-10 23:09:00+00:00
# ❌ No opportunity at 2025-06-10 23:10:00+00:00
# ❌ No opportunity at 2025-06-10 23:11:00+00:00
# ❌ No opportunity at 2025-06-10 23:12:00+00:00
# ❌ No opportunity at 2025-06-10 23:13:00+00:00
# ❌ No opportunity at 2025-06-10 23:14:00+00:00
# ❌ No opportunity at 2025-06-10 23:15:00+00:00
# ❌ No opportunity at 2025-06-10 23:16:00+00:00
# ❌ No opportunity at 2025-06-10 23:17:00+00:00
# ❌ No opportunity at 2025-06-10 23:18:00+00:00
# ❌ No opportunity at 2025-06-10 23:19:00+00:00
# ❌ No opportunity at 2025-06-10 23:20:00+00:00
# ❌ No opportunity at 2025-06-10 23:21:00+00:00
# ❌ No opportunity at 2025-06-10 23:22:00+00:00
# ❌ No opportunity at 2025-06-10 23:23:00+00:00
# ❌ No opportunity at 2025-06-10 23:24:00+00:00
# ❌ No opportunity at 2025-06-10 23:25:00+00:00
# ❌ No opportunity at 2025-06-10 23:26:00+00:00
# ❌ No opportunity at 2025-06-10 23:27:00+00:00
# ❌ No opportunity at 2025-06-10 23:28:00+00:00
# ❌ No opportunity at 2025-06-10 23:29:00+00:00
# ❌ No opportunity at 2025-06-10 23:30:00+00:00
# ❌ No opportunity at 2025-06-10 23:31:00+00:00
# ❌ No opportunity at 2025-06-10 23:32:00+00:00
# ❌ No opportunity at 2025-06-10 23:33:00+00:00
# ❌ No opportunity at 2025-06-10 23:34:00+00:00
# ❌ No opportunity at 2025-06-10 23:35:00+00:00
# ❌ No opportunity at 2025-06-10 23:36:00+00:00
# ❌ No opportunity at 2025-06-10 23:37:00+00:00
# ❌ No opportunity at 2025-06-10 23:38:00+00:00
# ❌ No opportunity at 2025-06-10 23:39:00+00:00
# ❌ No opportunity at 2025-06-10 23:40:00+00:00
# ❌ No opportunity at 2025-06-10 23:41:00+00:00
# ❌ No opportunity at 2025-06-10 23:42:00+00:00
# ❌ No opportunity at 2025-06-10 23:43:00+00:00
# ❌ No opportunity at 2025-06-10 23:44:00+00:00
# ❌ No opportunity at 2025-06-10 23:45:00+00:00
# ❌ No opportunity at 2025-06-10 23:46:00+00:00
# ❌ No opportunity at 2025-06-10 23:47:00+00:00
# ❌ No opportunity at 2025-06-10 23:48:00+00:00
# ❌ No opportunity at 2025-06-10 23:49:00+00:00
# ❌ No opportunity at 2025-06-10 23:50:00+00:00
# ❌ No opportunity at 2025-06-10 23:51:00+00:00
# ❌ No opportunity at 2025-06-10 23:52:00+00:00
# ❌ No opportunity at 2025-06-10 23:53:00+00:00
# ❌ No opportunity at 2025-06-10 23:54:00+00:00
# ❌ No opportunity at 2025-06-10 23:55:00+00:00
# ❌ No opportunity at 2025-06-10 23:56:00+00:00
# ❌ No opportunity at 2025-06-10 23:57:00+00:00
# ❌ No opportunity at 2025-06-10 23:58:00+00:00
# ❌ No opportunity at 2025-06-10 23:59:00+00:00
# ❌ No opportunity at 2025-06-11 00:00:00+00:00
# ❌ No opportunity at 2025-06-11 00:01:00+00:00
# ❌ No opportunity at 2025-06-11 00:02:00+00:00
# ❌ No opportunity at 2025-06-11 00:03:00+00:00
# ❌ No opportunity at 2025-06-11 00:04:00+00:00
# ❌ No opportunity at 2025-06-11 00:05:00+00:00
# ❌ No opportunity at 2025-06-11 00:06:00+00:00
# ❌ No opportunity at 2025-06-11 00:07:00+00:00
# ❌ No opportunity at 2025-06-11 00:08:00+00:00
# ❌ No opportunity at 2025-06-11 00:09:00+00:00
# ❌ No opportunity at 2025-06-11 00:10:00+00:00
# ❌ No opportunity at 2025-06-11 00:11:00+00:00
# ❌ No opportunity at 2025-06-11 00:12:00+00:00
# ❌ No opportunity at 2025-06-11 00:13:00+00:00
# ❌ No opportunity at 2025-06-11 00:14:00+00:00
# ❌ No opportunity at 2025-06-11 00:15:00+00:00
# ❌ No opportunity at 2025-06-11 00:16:00+00:00
# ❌ No opportunity at 2025-06-11 00:17:00+00:00
# ❌ No opportunity at 2025-06-11 00:18:00+00:00
# ❌ No opportunity at 2025-06-11 00:19:00+00:00
# ❌ No opportunity at 2025-06-11 00:20:00+00:00
# ❌ No opportunity at 2025-06-11 00:21:00+00:00
# ❌ No opportunity at 2025-06-11 00:22:00+00:00
# ❌ No opportunity at 2025-06-11 00:23:00+00:00
# ❌ No opportunity at 2025-06-11 00:24:00+00:00
# ❌ No opportunity at 2025-06-11 00:25:00+00:00
# ❌ No opportunity at 2025-06-11 00:26:00+00:00
# ❌ No opportunity at 2025-06-11 00:27:00+00:00
# ❌ No opportunity at 2025-06-11 00:28:00+00:00
# ❌ No opportunity at 2025-06-11 00:29:00+00:00
# ❌ No opportunity at 2025-06-11 00:30:00+00:00
# ❌ No opportunity at 2025-06-11 00:31:00+00:00
# ❌ No opportunity at 2025-06-11 00:32:00+00:00
# ❌ No opportunity at 2025-06-11 00:33:00+00:00
# ❌ No opportunity at 2025-06-11 00:34:00+00:00
# ❌ No opportunity at 2025-06-11 00:35:00+00:00
# ❌ No opportunity at 2025-06-11 00:36:00+00:00
# ❌ No opportunity at 2025-06-11 00:37:00+00:00
# ❌ No opportunity at 2025-06-11 00:38:00+00:00
# ❌ No opportunity at 2025-06-11 00:39:00+00:00
# ❌ No opportunity at 2025-06-11 00:40:00+00:00
# ❌ No opportunity at 2025-06-11 00:41:00+00:00
# ❌ No opportunity at 2025-06-11 00:42:00+00:00
# ❌ No opportunity at 2025-06-11 00:43:00+00:00
# ❌ No opportunity at 2025-06-11 00:44:00+00:00
# ❌ No opportunity at 2025-06-11 00:45:00+00:00
# ❌ No opportunity at 2025-06-11 00:46:00+00:00
# ❌ No opportunity at 2025-06-11 00:47:00+00:00
# ❌ No opportunity at 2025-06-11 00:48:00+00:00
# ❌ No opportunity at 2025-06-11 00:49:00+00:00
# ❌ No opportunity at 2025-06-11 00:50:00+00:00
# ❌ No opportunity at 2025-06-11 00:51:00+00:00
# ❌ No opportunity at 2025-06-11 00:52:00+00:00
# ❌ No opportunity at 2025-06-11 00:53:00+00:00
# ❌ No opportunity at 2025-06-11 00:54:00+00:00
# ❌ No opportunity at 2025-06-11 00:55:00+00:00
# ❌ No opportunity at 2025-06-11 00:56:00+00:00
# ❌ No opportunity at 2025-06-11 00:57:00+00:00
# ❌ No opportunity at 2025-06-11 00:58:00+00:00
# ❌ No opportunity at 2025-06-11 00:59:00+00:00
# ❌ No opportunity at 2025-06-11 01:00:00+00:00
# ❌ No opportunity at 2025-06-11 01:01:00+00:00
# ❌ No opportunity at 2025-06-11 01:02:00+00:00
# ❌ No opportunity at 2025-06-11 01:03:00+00:00
# ❌ No opportunity at 2025-06-11 01:04:00+00:00
# ❌ No opportunity at 2025-06-11 01:05:00+00:00
# ❌ No opportunity at 2025-06-11 01:06:00+00:00
# ❌ No opportunity at 2025-06-11 01:07:00+00:00
# ❌ No opportunity at 2025-06-11 01:08:00+00:00
# ❌ No opportunity at 2025-06-11 01:09:00+00:00
# ❌ No opportunity at 2025-06-11 01:10:00+00:00
# ❌ No opportunity at 2025-06-11 01:11:00+00:00
# ❌ No opportunity at 2025-06-11 01:12:00+00:00
# ❌ No opportunity at 2025-06-11 01:13:00+00:00
# ❌ No opportunity at 2025-06-11 01:14:00+00:00
# ❌ No opportunity at 2025-06-11 01:15:00+00:00
# ❌ No opportunity at 2025-06-11 01:16:00+00:00
# ❌ No opportunity at 2025-06-11 01:17:00+00:00
# ❌ No opportunity at 2025-06-11 01:18:00+00:00
# ❌ No opportunity at 2025-06-11 01:19:00+00:00
# ❌ No opportunity at 2025-06-11 01:20:00+00:00
# ❌ No opportunity at 2025-06-11 01:21:00+00:00
# ❌ No opportunity at 2025-06-11 01:22:00+00:00
# ❌ No opportunity at 2025-06-11 01:23:00+00:00
# ❌ No opportunity at 2025-06-11 01:24:00+00:00
# ❌ No opportunity at 2025-06-11 01:25:00+00:00
# ❌ No opportunity at 2025-06-11 01:26:00+00:00
# ❌ No opportunity at 2025-06-11 01:27:00+00:00
# ❌ No opportunity at 2025-06-11 01:28:00+00:00
# ❌ No opportunity at 2025-06-11 01:29:00+00:00
# ❌ No opportunity at 2025-06-11 01:30:00+00:00
# ❌ No opportunity at 2025-06-11 01:31:00+00:00
# ❌ No opportunity at 2025-06-11 01:32:00+00:00
# ❌ No opportunity at 2025-06-11 01:33:00+00:00
# ❌ No opportunity at 2025-06-11 01:34:00+00:00
# ❌ No opportunity at 2025-06-11 01:35:00+00:00
# ❌ No opportunity at 2025-06-11 01:36:00+00:00
# ❌ No opportunity at 2025-06-11 01:37:00+00:00
# ❌ No opportunity at 2025-06-11 01:38:00+00:00
# ❌ No opportunity at 2025-06-11 01:39:00+00:00
# ❌ No opportunity at 2025-06-11 01:40:00+00:00
# ❌ No opportunity at 2025-06-11 01:41:00+00:00
# ❌ No opportunity at 2025-06-11 01:42:00+00:00
# ❌ No opportunity at 2025-06-11 01:43:00+00:00
# ❌ No opportunity at 2025-06-11 01:44:00+00:00
# ❌ No opportunity at 2025-06-11 01:45:00+00:00
# ❌ No opportunity at 2025-06-11 01:46:00+00:00
# ❌ No opportunity at 2025-06-11 01:47:00+00:00
# ❌ No opportunity at 2025-06-11 01:48:00+00:00
# ❌ No opportunity at 2025-06-11 01:49:00+00:00
# ❌ No opportunity at 2025-06-11 01:50:00+00:00
# ❌ No opportunity at 2025-06-11 01:51:00+00:00
# ❌ No opportunity at 2025-06-11 01:52:00+00:00
# ❌ No opportunity at 2025-06-11 01:53:00+00:00
# ❌ No opportunity at 2025-06-11 01:54:00+00:00
# ❌ No opportunity at 2025-06-11 01:55:00+00:00
# ❌ No opportunity at 2025-06-11 01:56:00+00:00
# ❌ No opportunity at 2025-06-11 01:57:00+00:00
# ❌ No opportunity at 2025-06-11 01:58:00+00:00
# ❌ No opportunity at 2025-06-11 01:59:00+00:00
# ❌ No opportunity at 2025-06-11 02:00:00+00:00
# ❌ No opportunity at 2025-06-11 02:01:00+00:00
# ❌ No opportunity at 2025-06-11 02:02:00+00:00
# ❌ No opportunity at 2025-06-11 02:03:00+00:00
# ❌ No opportunity at 2025-06-11 02:04:00+00:00
# ❌ No opportunity at 2025-06-11 02:05:00+00:00
# ❌ No opportunity at 2025-06-11 02:06:00+00:00
# ❌ No opportunity at 2025-06-11 02:07:00+00:00
# ❌ No opportunity at 2025-06-11 02:08:00+00:00
# ❌ No opportunity at 2025-06-11 02:09:00+00:00
# ❌ No opportunity at 2025-06-11 02:10:00+00:00
# ❌ No opportunity at 2025-06-11 02:11:00+00:00
# ❌ No opportunity at 2025-06-11 02:12:00+00:00
# ❌ No opportunity at 2025-06-11 02:13:00+00:00
# ❌ No opportunity at 2025-06-11 02:14:00+00:00
# ❌ No opportunity at 2025-06-11 02:15:00+00:00
# ❌ No opportunity at 2025-06-11 02:16:00+00:00
# ❌ No opportunity at 2025-06-11 02:17:00+00:00
# ❌ No opportunity at 2025-06-11 02:18:00+00:00
# ❌ No opportunity at 2025-06-11 02:19:00+00:00
# ❌ No opportunity at 2025-06-11 02:20:00+00:00
# ❌ No opportunity at 2025-06-11 02:21:00+00:00
# ❌ No opportunity at 2025-06-11 02:22:00+00:00
# ❌ No opportunity at 2025-06-11 02:23:00+00:00
# ❌ No opportunity at 2025-06-11 02:24:00+00:00
# ❌ No opportunity at 2025-06-11 02:25:00+00:00
# ❌ No opportunity at 2025-06-11 02:26:00+00:00
# ❌ No opportunity at 2025-06-11 02:27:00+00:00
# ❌ No opportunity at 2025-06-11 02:28:00+00:00
# ❌ No opportunity at 2025-06-11 02:29:00+00:00
# ❌ No opportunity at 2025-06-11 02:30:00+00:00
# ❌ No opportunity at 2025-06-11 02:31:00+00:00
# ❌ No opportunity at 2025-06-11 02:32:00+00:00
# ❌ No opportunity at 2025-06-11 02:33:00+00:00
# ❌ No opportunity at 2025-06-11 02:34:00+00:00
# ❌ No opportunity at 2025-06-11 02:35:00+00:00
# ❌ No opportunity at 2025-06-11 02:36:00+00:00
# ❌ No opportunity at 2025-06-11 02:37:00+00:00
# ❌ No opportunity at 2025-06-11 02:38:00+00:00
# ❌ No opportunity at 2025-06-11 02:39:00+00:00
# ❌ No opportunity at 2025-06-11 02:40:00+00:00
# ❌ No opportunity at 2025-06-11 02:41:00+00:00
# ❌ No opportunity at 2025-06-11 02:42:00+00:00
# ❌ No opportunity at 2025-06-11 02:43:00+00:00
# ❌ No opportunity at 2025-06-11 02:44:00+00:00
# ❌ No opportunity at 2025-06-11 02:45:00+00:00
# ❌ No opportunity at 2025-06-11 02:46:00+00:00
# ❌ No opportunity at 2025-06-11 02:47:00+00:00
# ❌ No opportunity at 2025-06-11 02:48:00+00:00
# ❌ No opportunity at 2025-06-11 02:49:00+00:00
# ❌ No opportunity at 2025-06-11 02:50:00+00:00
# ❌ No opportunity at 2025-06-11 02:51:00+00:00
# ❌ No opportunity at 2025-06-11 02:52:00+00:00
# ❌ No opportunity at 2025-06-11 02:53:00+00:00
# ❌ No opportunity at 2025-06-11 02:54:00+00:00
# ❌ No opportunity at 2025-06-11 02:55:00+00:00
# ❌ No opportunity at 2025-06-11 02:56:00+00:00
# ❌ No opportunity at 2025-06-11 02:57:00+00:00
# ❌ No opportunity at 2025-06-11 02:58:00+00:00
# ❌ No opportunity at 2025-06-11 02:59:00+00:00
# ❌ No opportunity at 2025-06-11 03:00:00+00:00
# ❌ No opportunity at 2025-06-11 03:01:00+00:00
# ❌ No opportunity at 2025-06-11 03:02:00+00:00
# ❌ No opportunity at 2025-06-11 03:03:00+00:00
# ❌ No opportunity at 2025-06-11 03:04:00+00:00
# ❌ No opportunity at 2025-06-11 03:05:00+00:00
# ❌ No opportunity at 2025-06-11 03:06:00+00:00
# ❌ No opportunity at 2025-06-11 03:07:00+00:00
# ❌ No opportunity at 2025-06-11 03:08:00+00:00
# ❌ No opportunity at 2025-06-11 03:09:00+00:00
# ❌ No opportunity at 2025-06-11 03:10:00+00:00
# ❌ No opportunity at 2025-06-11 03:11:00+00:00
# ❌ No opportunity at 2025-06-11 03:12:00+00:00
# ❌ No opportunity at 2025-06-11 03:13:00+00:00
# ❌ No opportunity at 2025-06-11 03:14:00+00:00
# ❌ No opportunity at 2025-06-11 03:15:00+00:00
# ❌ No opportunity at 2025-06-11 03:16:00+00:00
# ❌ No opportunity at 2025-06-11 03:17:00+00:00
# ❌ No opportunity at 2025-06-11 03:18:00+00:00
# ❌ No opportunity at 2025-06-11 03:19:00+00:00
# ❌ No opportunity at 2025-06-11 03:20:00+00:00
# ❌ No opportunity at 2025-06-11 03:21:00+00:00
# ❌ No opportunity at 2025-06-11 03:22:00+00:00
# ❌ No opportunity at 2025-06-11 03:23:00+00:00
# ❌ No opportunity at 2025-06-11 03:24:00+00:00
# ❌ No opportunity at 2025-06-11 03:25:00+00:00
# ❌ No opportunity at 2025-06-11 03:26:00+00:00
# ❌ No opportunity at 2025-06-11 03:27:00+00:00
# ❌ No opportunity at 2025-06-11 03:28:00+00:00
# ❌ No opportunity at 2025-06-11 03:29:00+00:00
# ❌ No opportunity at 2025-06-11 03:30:00+00:00
# ❌ No opportunity at 2025-06-11 03:31:00+00:00
# ❌ No opportunity at 2025-06-11 03:32:00+00:00
# ❌ No opportunity at 2025-06-11 03:33:00+00:00
# ❌ No opportunity at 2025-06-11 03:34:00+00:00
# ❌ No opportunity at 2025-06-11 03:35:00+00:00
# ❌ No opportunity at 2025-06-11 03:36:00+00:00
# ❌ No opportunity at 2025-06-11 03:37:00+00:00
# ❌ No opportunity at 2025-06-11 03:38:00+00:00
# ❌ No opportunity at 2025-06-11 03:39:00+00:00
# ❌ No opportunity at 2025-06-11 03:40:00+00:00
# ❌ No opportunity at 2025-06-11 03:41:00+00:00
# ❌ No opportunity at 2025-06-11 03:42:00+00:00
# ❌ No opportunity at 2025-06-11 03:43:00+00:00
# ❌ No opportunity at 2025-06-11 03:44:00+00:00
# ❌ No opportunity at 2025-06-11 03:45:00+00:00
# ❌ No opportunity at 2025-06-11 03:46:00+00:00
# ❌ No opportunity at 2025-06-11 03:47:00+00:00
# ❌ No opportunity at 2025-06-11 03:48:00+00:00
# ❌ No opportunity at 2025-06-11 03:49:00+00:00
# ❌ No opportunity at 2025-06-11 03:50:00+00:00
# ❌ No opportunity at 2025-06-11 03:51:00+00:00
# ❌ No opportunity at 2025-06-11 03:52:00+00:00
# ❌ No opportunity at 2025-06-11 03:53:00+00:00
# ❌ No opportunity at 2025-06-11 03:54:00+00:00
# ❌ No opportunity at 2025-06-11 03:55:00+00:00
# ❌ No opportunity at 2025-06-11 03:56:00+00:00
# ❌ No opportunity at 2025-06-11 03:57:00+00:00
# ❌ No opportunity at 2025-06-11 03:58:00+00:00
# ❌ No opportunity at 2025-06-11 03:59:00+00:00
# ❌ No opportunity at 2025-06-11 04:00:00+00:00
# ❌ No opportunity at 2025-06-11 04:01:00+00:00
# ❌ No opportunity at 2025-06-11 04:02:00+00:00
# ❌ No opportunity at 2025-06-11 04:03:00+00:00
# ❌ No opportunity at 2025-06-11 04:04:00+00:00
# ❌ No opportunity at 2025-06-11 04:05:00+00:00
# ❌ No opportunity at 2025-06-11 04:06:00+00:00
# ❌ No opportunity at 2025-06-11 04:07:00+00:00
# ❌ No opportunity at 2025-06-11 04:08:00+00:00
# ❌ No opportunity at 2025-06-11 04:09:00+00:00
# ❌ No opportunity at 2025-06-11 04:10:00+00:00
# ❌ No opportunity at 2025-06-11 04:11:00+00:00
# ❌ No opportunity at 2025-06-11 04:12:00+00:00
# ❌ No opportunity at 2025-06-11 04:13:00+00:00
# ❌ No opportunity at 2025-06-11 04:14:00+00:00
# ❌ No opportunity at 2025-06-11 04:15:00+00:00
# ❌ No opportunity at 2025-06-11 04:16:00+00:00
# ❌ No opportunity at 2025-06-11 04:17:00+00:00
# ❌ No opportunity at 2025-06-11 04:18:00+00:00
# ❌ No opportunity at 2025-06-11 04:19:00+00:00
# ❌ No opportunity at 2025-06-11 04:20:00+00:00
# ❌ No opportunity at 2025-06-11 04:21:00+00:00
# ❌ No opportunity at 2025-06-11 04:22:00+00:00
# ❌ No opportunity at 2025-06-11 04:23:00+00:00
# ❌ No opportunity at 2025-06-11 04:24:00+00:00
# ❌ No opportunity at 2025-06-11 04:25:00+00:00
# ❌ No opportunity at 2025-06-11 04:26:00+00:00
# ❌ No opportunity at 2025-06-11 04:27:00+00:00
# ❌ No opportunity at 2025-06-11 04:28:00+00:00
# ❌ No opportunity at 2025-06-11 04:29:00+00:00
# ❌ No opportunity at 2025-06-11 04:30:00+00:00
# ❌ No opportunity at 2025-06-11 04:31:00+00:00
# ❌ No opportunity at 2025-06-11 04:32:00+00:00
# ❌ No opportunity at 2025-06-11 04:33:00+00:00
# ❌ No opportunity at 2025-06-11 04:34:00+00:00
# ❌ No opportunity at 2025-06-11 04:35:00+00:00
# ❌ No opportunity at 2025-06-11 04:36:00+00:00
# ❌ No opportunity at 2025-06-11 04:37:00+00:00
# ❌ No opportunity at 2025-06-11 04:38:00+00:00
# ❌ No opportunity at 2025-06-11 04:39:00+00:00
# ❌ No opportunity at 2025-06-11 04:40:00+00:00
# ❌ No opportunity at 2025-06-11 04:41:00+00:00
# ❌ No opportunity at 2025-06-11 04:42:00+00:00
# ❌ No opportunity at 2025-06-11 04:43:00+00:00
# ❌ No opportunity at 2025-06-11 04:44:00+00:00
# ❌ No opportunity at 2025-06-11 04:45:00+00:00
# ❌ No opportunity at 2025-06-11 04:46:00+00:00
# ❌ No opportunity at 2025-06-11 04:47:00+00:00
# ❌ No opportunity at 2025-06-11 04:48:00+00:00
# ❌ No opportunity at 2025-06-11 04:49:00+00:00
# ❌ No opportunity at 2025-06-11 04:50:00+00:00
# ❌ No opportunity at 2025-06-11 04:51:00+00:00
# ❌ No opportunity at 2025-06-11 04:52:00+00:00
# ❌ No opportunity at 2025-06-11 04:53:00+00:00
# ❌ No opportunity at 2025-06-11 04:54:00+00:00
# ❌ No opportunity at 2025-06-11 04:55:00+00:00
# ❌ No opportunity at 2025-06-11 04:56:00+00:00
# ❌ No opportunity at 2025-06-11 04:57:00+00:00
# ❌ No opportunity at 2025-06-11 04:58:00+00:00
# ❌ No opportunity at 2025-06-11 04:59:00+00:00
# ❌ No opportunity at 2025-06-11 05:00:00+00:00
# ❌ No opportunity at 2025-06-11 05:01:00+00:00
# ❌ No opportunity at 2025-06-11 05:02:00+00:00
# ❌ No opportunity at 2025-06-11 05:03:00+00:00
# ❌ No opportunity at 2025-06-11 05:04:00+00:00
# ❌ No opportunity at 2025-06-11 05:05:00+00:00
# ❌ No opportunity at 2025-06-11 05:06:00+00:00
# ❌ No opportunity at 2025-06-11 05:07:00+00:00
# ❌ No opportunity at 2025-06-11 05:08:00+00:00
# ❌ No opportunity at 2025-06-11 05:09:00+00:00
# ❌ No opportunity at 2025-06-11 05:10:00+00:00
# ❌ No opportunity at 2025-06-11 05:11:00+00:00
# ❌ No opportunity at 2025-06-11 05:12:00+00:00
# ❌ No opportunity at 2025-06-11 05:13:00+00:00
# ❌ No opportunity at 2025-06-11 05:14:00+00:00
# ❌ No opportunity at 2025-06-11 05:15:00+00:00
# ❌ No opportunity at 2025-06-11 05:16:00+00:00
# ❌ No opportunity at 2025-06-11 05:17:00+00:00
# ❌ No opportunity at 2025-06-11 05:18:00+00:00
# ❌ No opportunity at 2025-06-11 05:19:00+00:00
# ❌ No opportunity at 2025-06-11 05:20:00+00:00
# ❌ No opportunity at 2025-06-11 05:21:00+00:00
# ❌ No opportunity at 2025-06-11 05:22:00+00:00
# ❌ No opportunity at 2025-06-11 05:23:00+00:00
# ❌ No opportunity at 2025-06-11 05:24:00+00:00
# ❌ No opportunity at 2025-06-11 05:25:00+00:00
# ❌ No opportunity at 2025-06-11 05:26:00+00:00
# ❌ No opportunity at 2025-06-11 05:27:00+00:00
# ❌ No opportunity at 2025-06-11 05:28:00+00:00
# ❌ No opportunity at 2025-06-11 05:29:00+00:00
# ❌ No opportunity at 2025-06-11 05:30:00+00:00
# ❌ No opportunity at 2025-06-11 05:31:00+00:00
# ❌ No opportunity at 2025-06-11 05:32:00+00:00
# ❌ No opportunity at 2025-06-11 05:33:00+00:00
# ❌ No opportunity at 2025-06-11 05:34:00+00:00
# ❌ No opportunity at 2025-06-11 05:35:00+00:00
# ❌ No opportunity at 2025-06-11 05:36:00+00:00
# ❌ No opportunity at 2025-06-11 05:37:00+00:00
# ❌ No opportunity at 2025-06-11 05:38:00+00:00
# ❌ No opportunity at 2025-06-11 05:39:00+00:00
# ❌ No opportunity at 2025-06-11 05:40:00+00:00
# ❌ No opportunity at 2025-06-11 05:41:00+00:00
# ❌ No opportunity at 2025-06-11 05:42:00+00:00
# ❌ No opportunity at 2025-06-11 05:43:00+00:00
# ❌ No opportunity at 2025-06-11 05:44:00+00:00
# ❌ No opportunity at 2025-06-11 05:45:00+00:00
# ❌ No opportunity at 2025-06-11 05:46:00+00:00
# ❌ No opportunity at 2025-06-11 05:47:00+00:00
# ❌ No opportunity at 2025-06-11 05:48:00+00:00
# ❌ No opportunity at 2025-06-11 05:49:00+00:00
# ❌ No opportunity at 2025-06-11 05:50:00+00:00
# ❌ No opportunity at 2025-06-11 05:51:00+00:00
# ❌ No opportunity at 2025-06-11 05:52:00+00:00
# ❌ No opportunity at 2025-06-11 05:53:00+00:00
# ❌ No opportunity at 2025-06-11 05:54:00+00:00
# ❌ No opportunity at 2025-06-11 05:55:00+00:00
# ❌ No opportunity at 2025-06-11 05:56:00+00:00
# ❌ No opportunity at 2025-06-11 05:57:00+00:00
# ❌ No opportunity at 2025-06-11 05:58:00+00:00
# ❌ No opportunity at 2025-06-11 05:59:00+00:00
# ❌ No opportunity at 2025-06-11 06:00:00+00:00
# ❌ No opportunity at 2025-06-11 06:01:00+00:00
# ❌ No opportunity at 2025-06-11 06:02:00+00:00
# ❌ No opportunity at 2025-06-11 06:03:00+00:00
# ❌ No opportunity at 2025-06-11 06:04:00+00:00
# ❌ No opportunity at 2025-06-11 06:05:00+00:00
# ❌ No opportunity at 2025-06-11 06:06:00+00:00
# ❌ No opportunity at 2025-06-11 06:07:00+00:00
# ❌ No opportunity at 2025-06-11 06:08:00+00:00
# ❌ No opportunity at 2025-06-11 06:09:00+00:00
# ❌ No opportunity at 2025-06-11 06:10:00+00:00
# ❌ No opportunity at 2025-06-11 06:11:00+00:00
# ❌ No opportunity at 2025-06-11 06:12:00+00:00
# ❌ No opportunity at 2025-06-11 06:13:00+00:00
# ❌ No opportunity at 2025-06-11 06:14:00+00:00
# ❌ No opportunity at 2025-06-11 06:15:00+00:00
# ❌ No opportunity at 2025-06-11 06:16:00+00:00
# ❌ No opportunity at 2025-06-11 06:17:00+00:00
# ❌ No opportunity at 2025-06-11 06:18:00+00:00
# ❌ No opportunity at 2025-06-11 06:19:00+00:00
# ❌ No opportunity at 2025-06-11 06:20:00+00:00
# ❌ No opportunity at 2025-06-11 06:21:00+00:00
# ❌ No opportunity at 2025-06-11 06:22:00+00:00
# ❌ No opportunity at 2025-06-11 06:23:00+00:00
# ❌ No opportunity at 2025-06-11 06:24:00+00:00
# ❌ No opportunity at 2025-06-11 06:25:00+00:00
# ❌ No opportunity at 2025-06-11 06:26:00+00:00
# ❌ No opportunity at 2025-06-11 06:27:00+00:00
# ❌ No opportunity at 2025-06-11 06:28:00+00:00
# ❌ No opportunity at 2025-06-11 06:29:00+00:00
# ❌ No opportunity at 2025-06-11 06:30:00+00:00
# ❌ No opportunity at 2025-06-11 06:31:00+00:00
# ❌ No opportunity at 2025-06-11 06:32:00+00:00
# ❌ No opportunity at 2025-06-11 06:33:00+00:00
# ❌ No opportunity at 2025-06-11 06:34:00+00:00
# ❌ No opportunity at 2025-06-11 06:35:00+00:00
# ❌ No opportunity at 2025-06-11 06:36:00+00:00
# ❌ No opportunity at 2025-06-11 06:37:00+00:00
# ❌ No opportunity at 2025-06-11 06:38:00+00:00
# ❌ No opportunity at 2025-06-11 06:39:00+00:00
# ❌ No opportunity at 2025-06-11 06:40:00+00:00
# ❌ No opportunity at 2025-06-11 06:41:00+00:00
# ❌ No opportunity at 2025-06-11 06:42:00+00:00
# ❌ No opportunity at 2025-06-11 06:43:00+00:00
# ❌ No opportunity at 2025-06-11 06:44:00+00:00
# ❌ No opportunity at 2025-06-11 06:45:00+00:00
# ❌ No opportunity at 2025-06-11 06:46:00+00:00
# ❌ No opportunity at 2025-06-11 06:47:00+00:00
# ❌ No opportunity at 2025-06-11 06:48:00+00:00
# ❌ No opportunity at 2025-06-11 06:49:00+00:00
# ❌ No opportunity at 2025-06-11 06:50:00+00:00
# ❌ No opportunity at 2025-06-11 06:51:00+00:00
# ❌ No opportunity at 2025-06-11 06:52:00+00:00
# ❌ No opportunity at 2025-06-11 06:53:00+00:00
# ❌ No opportunity at 2025-06-11 06:54:00+00:00
# ❌ No opportunity at 2025-06-11 06:55:00+00:00
# ❌ No opportunity at 2025-06-11 06:56:00+00:00
# ❌ No opportunity at 2025-06-11 06:57:00+00:00
# ❌ No opportunity at 2025-06-11 06:58:00+00:00
# ❌ No opportunity at 2025-06-11 06:59:00+00:00
# ❌ No opportunity at 2025-06-11 07:00:00+00:00
# ❌ No opportunity at 2025-06-11 07:01:00+00:00
# ❌ No opportunity at 2025-06-11 07:02:00+00:00
# ❌ No opportunity at 2025-06-11 07:03:00+00:00
# ❌ No opportunity at 2025-06-11 07:04:00+00:00
# ❌ No opportunity at 2025-06-11 07:05:00+00:00
# ❌ No opportunity at 2025-06-11 07:06:00+00:00
# ❌ No opportunity at 2025-06-11 07:07:00+00:00
# ❌ No opportunity at 2025-06-11 07:08:00+00:00
# ❌ No opportunity at 2025-06-11 07:09:00+00:00
# ❌ No opportunity at 2025-06-11 07:10:00+00:00
# ❌ No opportunity at 2025-06-11 07:11:00+00:00
# ❌ No opportunity at 2025-06-11 07:12:00+00:00
# ❌ No opportunity at 2025-06-11 07:13:00+00:00
# ❌ No opportunity at 2025-06-11 07:14:00+00:00
# ❌ No opportunity at 2025-06-11 07:15:00+00:00
# ❌ No opportunity at 2025-06-11 07:16:00+00:00
# ❌ No opportunity at 2025-06-11 07:17:00+00:00
# ❌ No opportunity at 2025-06-11 07:18:00+00:00
# ❌ No opportunity at 2025-06-11 07:19:00+00:00
# ❌ No opportunity at 2025-06-11 07:20:00+00:00
# ❌ No opportunity at 2025-06-11 07:21:00+00:00
# ❌ No opportunity at 2025-06-11 07:22:00+00:00
# ❌ No opportunity at 2025-06-11 07:23:00+00:00
# ❌ No opportunity at 2025-06-11 07:24:00+00:00
# ❌ No opportunity at 2025-06-11 07:25:00+00:00
# ❌ No opportunity at 2025-06-11 07:26:00+00:00
# ❌ No opportunity at 2025-06-11 07:27:00+00:00
# ❌ No opportunity at 2025-06-11 07:28:00+00:00
# ❌ No opportunity at 2025-06-11 07:29:00+00:00
# ❌ No opportunity at 2025-06-11 07:30:00+00:00
# ❌ No opportunity at 2025-06-11 07:31:00+00:00
# ❌ No opportunity at 2025-06-11 07:32:00+00:00
# ❌ No opportunity at 2025-06-11 07:33:00+00:00
# ❌ No opportunity at 2025-06-11 07:34:00+00:00
# ❌ No opportunity at 2025-06-11 07:35:00+00:00
# ❌ No opportunity at 2025-06-11 07:36:00+00:00
# ❌ No opportunity at 2025-06-11 07:37:00+00:00
# ❌ No opportunity at 2025-06-11 07:38:00+00:00
# ❌ No opportunity at 2025-06-11 07:39:00+00:00
# ❌ No opportunity at 2025-06-11 07:40:00+00:00
# ❌ No opportunity at 2025-06-11 07:41:00+00:00
# ❌ No opportunity at 2025-06-11 07:42:00+00:00
# ❌ No opportunity at 2025-06-11 07:43:00+00:00
# ❌ No opportunity at 2025-06-11 07:44:00+00:00
# ❌ No opportunity at 2025-06-11 07:45:00+00:00
# ❌ No opportunity at 2025-06-11 07:46:00+00:00
# ❌ No opportunity at 2025-06-11 07:47:00+00:00
# ❌ No opportunity at 2025-06-11 07:48:00+00:00
# ❌ No opportunity at 2025-06-11 07:49:00+00:00
# ❌ No opportunity at 2025-06-11 07:50:00+00:00
# ❌ No opportunity at 2025-06-11 07:51:00+00:00
# ❌ No opportunity at 2025-06-11 07:52:00+00:00
# ❌ No opportunity at 2025-06-11 07:53:00+00:00
# ❌ No opportunity at 2025-06-11 07:54:00+00:00
# ❌ No opportunity at 2025-06-11 07:55:00+00:00
# ❌ No opportunity at 2025-06-11 07:56:00+00:00
# ❌ No opportunity at 2025-06-11 07:57:00+00:00
# ❌ No opportunity at 2025-06-11 07:58:00+00:00
# ❌ No opportunity at 2025-06-11 07:59:00+00:00
# ❌ No opportunity at 2025-06-11 08:00:00+00:00
# ❌ No opportunity at 2025-06-11 08:01:00+00:00
# ❌ No opportunity at 2025-06-11 08:02:00+00:00
# ❌ No opportunity at 2025-06-11 08:03:00+00:00
# ❌ No opportunity at 2025-06-11 08:04:00+00:00
# ❌ No opportunity at 2025-06-11 08:05:00+00:00
# ❌ No opportunity at 2025-06-11 08:06:00+00:00
# ❌ No opportunity at 2025-06-11 08:07:00+00:00
# ❌ No opportunity at 2025-06-11 08:08:00+00:00
# ❌ No opportunity at 2025-06-11 08:09:00+00:00
# ❌ No opportunity at 2025-06-11 08:10:00+00:00
# ❌ No opportunity at 2025-06-11 08:11:00+00:00
# ❌ No opportunity at 2025-06-11 08:12:00+00:00
# ❌ No opportunity at 2025-06-11 08:13:00+00:00
# ❌ No opportunity at 2025-06-11 08:14:00+00:00
# ❌ No opportunity at 2025-06-11 08:15:00+00:00
# ❌ No opportunity at 2025-06-11 08:16:00+00:00
# ❌ No opportunity at 2025-06-11 08:17:00+00:00
# ❌ No opportunity at 2025-06-11 08:18:00+00:00
# ❌ No opportunity at 2025-06-11 08:19:00+00:00
# ❌ No opportunity at 2025-06-11 08:20:00+00:00
# ❌ No opportunity at 2025-06-11 08:21:00+00:00
# ❌ No opportunity at 2025-06-11 08:22:00+00:00
# ❌ No opportunity at 2025-06-11 08:23:00+00:00
# ❌ No opportunity at 2025-06-11 08:24:00+00:00
# ❌ No opportunity at 2025-06-11 08:25:00+00:00
# ❌ No opportunity at 2025-06-11 08:26:00+00:00
# ❌ No opportunity at 2025-06-11 08:27:00+00:00
# ❌ No opportunity at 2025-06-11 08:28:00+00:00
# ❌ No opportunity at 2025-06-11 08:29:00+00:00
# ❌ No opportunity at 2025-06-11 08:30:00+00:00
# ❌ No opportunity at 2025-06-11 08:31:00+00:00
# ❌ No opportunity at 2025-06-11 08:32:00+00:00
# ❌ No opportunity at 2025-06-11 08:33:00+00:00
# ❌ No opportunity at 2025-06-11 08:34:00+00:00
# ❌ No opportunity at 2025-06-11 08:35:00+00:00
# ❌ No opportunity at 2025-06-11 08:36:00+00:00
# ❌ No opportunity at 2025-06-11 08:37:00+00:00
# ❌ No opportunity at 2025-06-11 08:38:00+00:00
# ❌ No opportunity at 2025-06-11 08:39:00+00:00
# ❌ No opportunity at 2025-06-11 08:40:00+00:00
# ❌ No opportunity at 2025-06-11 08:41:00+00:00
# ❌ No opportunity at 2025-06-11 08:42:00+00:00
# ❌ No opportunity at 2025-06-11 08:43:00+00:00
# ❌ No opportunity at 2025-06-11 08:44:00+00:00
# ❌ No opportunity at 2025-06-11 08:45:00+00:00
# ❌ No opportunity at 2025-06-11 08:46:00+00:00
# ❌ No opportunity at 2025-06-11 08:47:00+00:00
# ❌ No opportunity at 2025-06-11 08:48:00+00:00
# ❌ No opportunity at 2025-06-11 08:49:00+00:00
# ❌ No opportunity at 2025-06-11 08:50:00+00:00
# ❌ No opportunity at 2025-06-11 08:51:00+00:00
# ❌ No opportunity at 2025-06-11 08:52:00+00:00
# ❌ No opportunity at 2025-06-11 08:53:00+00:00
# ❌ No opportunity at 2025-06-11 08:54:00+00:00
# ❌ No opportunity at 2025-06-11 08:55:00+00:00
# ❌ No opportunity at 2025-06-11 08:56:00+00:00
# ❌ No opportunity at 2025-06-11 08:57:00+00:00
# ❌ No opportunity at 2025-06-11 08:58:00+00:00
# ❌ No opportunity at 2025-06-11 08:59:00+00:00
# ❌ No opportunity at 2025-06-11 09:00:00+00:00
# ❌ No opportunity at 2025-06-11 09:01:00+00:00
# ❌ No opportunity at 2025-06-11 09:02:00+00:00
# ❌ No opportunity at 2025-06-11 09:03:00+00:00
# ❌ No opportunity at 2025-06-11 09:04:00+00:00
# ❌ No opportunity at 2025-06-11 09:05:00+00:00
# ❌ No opportunity at 2025-06-11 09:06:00+00:00
# ❌ No opportunity at 2025-06-11 09:07:00+00:00
# ❌ No opportunity at 2025-06-11 09:08:00+00:00
# ❌ No opportunity at 2025-06-11 09:09:00+00:00
# ❌ No opportunity at 2025-06-11 09:10:00+00:00
# ❌ No opportunity at 2025-06-11 09:11:00+00:00
# ❌ No opportunity at 2025-06-11 09:12:00+00:00
# ❌ No opportunity at 2025-06-11 09:13:00+00:00
# ❌ No opportunity at 2025-06-11 09:14:00+00:00
# ❌ No opportunity at 2025-06-11 09:15:00+00:00
# ❌ No opportunity at 2025-06-11 09:16:00+00:00
# ❌ No opportunity at 2025-06-11 09:17:00+00:00
# ❌ No opportunity at 2025-06-11 09:18:00+00:00
# ❌ No opportunity at 2025-06-11 09:19:00+00:00
# ❌ No opportunity at 2025-06-11 09:20:00+00:00
# ❌ No opportunity at 2025-06-11 09:21:00+00:00
# ❌ No opportunity at 2025-06-11 09:22:00+00:00
# ❌ No opportunity at 2025-06-11 09:23:00+00:00
# ❌ No opportunity at 2025-06-11 09:24:00+00:00
# ❌ No opportunity at 2025-06-11 09:25:00+00:00
# ❌ No opportunity at 2025-06-11 09:26:00+00:00
# ❌ No opportunity at 2025-06-11 09:27:00+00:00
# ❌ No opportunity at 2025-06-11 09:28:00+00:00
# ❌ No opportunity at 2025-06-11 09:29:00+00:00
# ❌ No opportunity at 2025-06-11 09:30:00+00:00
# ❌ No opportunity at 2025-06-11 09:31:00+00:00
# ❌ No opportunity at 2025-06-11 09:32:00+00:00
# ❌ No opportunity at 2025-06-11 09:33:00+00:00
# ❌ No opportunity at 2025-06-11 09:34:00+00:00
# ❌ No opportunity at 2025-06-11 09:35:00+00:00
# ❌ No opportunity at 2025-06-11 09:36:00+00:00
# ❌ No opportunity at 2025-06-11 09:37:00+00:00
# ❌ No opportunity at 2025-06-11 09:38:00+00:00
# ❌ No opportunity at 2025-06-11 09:39:00+00:00
# ❌ No opportunity at 2025-06-11 09:40:00+00:00
# ❌ No opportunity at 2025-06-11 09:41:00+00:00
# ❌ No opportunity at 2025-06-11 09:42:00+00:00
# ❌ No opportunity at 2025-06-11 09:43:00+00:00
# ❌ No opportunity at 2025-06-11 09:44:00+00:00
# ❌ No opportunity at 2025-06-11 09:45:00+00:00
# ❌ No opportunity at 2025-06-11 09:46:00+00:00
# ❌ No opportunity at 2025-06-11 09:47:00+00:00
# ❌ No opportunity at 2025-06-11 09:48:00+00:00
# ❌ No opportunity at 2025-06-11 09:49:00+00:00
# ❌ No opportunity at 2025-06-11 09:50:00+00:00
# ❌ No opportunity at 2025-06-11 09:51:00+00:00
# ❌ No opportunity at 2025-06-11 09:52:00+00:00
# ❌ No opportunity at 2025-06-11 09:53:00+00:00
# ❌ No opportunity at 2025-06-11 09:54:00+00:00
# ❌ No opportunity at 2025-06-11 09:55:00+00:00
# ❌ No opportunity at 2025-06-11 09:56:00+00:00
# ❌ No opportunity at 2025-06-11 09:57:00+00:00
# ❌ No opportunity at 2025-06-11 09:58:00+00:00
# ❌ No opportunity at 2025-06-11 09:59:00+00:00
# ❌ No opportunity at 2025-06-11 10:00:00+00:00
# ❌ No opportunity at 2025-06-11 10:01:00+00:00
# ❌ No opportunity at 2025-06-11 10:02:00+00:00
# ❌ No opportunity at 2025-06-11 10:03:00+00:00
# ❌ No opportunity at 2025-06-11 10:04:00+00:00
# ❌ No opportunity at 2025-06-11 10:05:00+00:00
# ❌ No opportunity at 2025-06-11 10:06:00+00:00
# ❌ No opportunity at 2025-06-11 10:07:00+00:00
# ❌ No opportunity at 2025-06-11 10:08:00+00:00
# ❌ No opportunity at 2025-06-11 10:09:00+00:00
# ❌ No opportunity at 2025-06-11 10:10:00+00:00
# ❌ No opportunity at 2025-06-11 10:11:00+00:00
# ❌ No opportunity at 2025-06-11 10:12:00+00:00
# ❌ No opportunity at 2025-06-11 10:13:00+00:00
# ❌ No opportunity at 2025-06-11 10:14:00+00:00
# ❌ No opportunity at 2025-06-11 10:15:00+00:00
# ❌ No opportunity at 2025-06-11 10:16:00+00:00
# ❌ No opportunity at 2025-06-11 10:17:00+00:00
# ❌ No opportunity at 2025-06-11 10:18:00+00:00
# ❌ No opportunity at 2025-06-11 10:19:00+00:00
# ❌ No opportunity at 2025-06-11 10:20:00+00:00
# ❌ No opportunity at 2025-06-11 10:21:00+00:00
# ❌ No opportunity at 2025-06-11 10:22:00+00:00
# ❌ No opportunity at 2025-06-11 10:23:00+00:00
# ❌ No opportunity at 2025-06-11 10:24:00+00:00
# ❌ No opportunity at 2025-06-11 10:25:00+00:00
# ❌ No opportunity at 2025-06-11 10:26:00+00:00
# ❌ No opportunity at 2025-06-11 10:27:00+00:00
# ❌ No opportunity at 2025-06-11 10:28:00+00:00
# ❌ No opportunity at 2025-06-11 10:29:00+00:00
# ❌ No opportunity at 2025-06-11 10:30:00+00:00
# ❌ No opportunity at 2025-06-11 10:31:00+00:00
# ❌ No opportunity at 2025-06-11 10:32:00+00:00
# ❌ No opportunity at 2025-06-11 10:33:00+00:00
# ❌ No opportunity at 2025-06-11 10:34:00+00:00
# ❌ No opportunity at 2025-06-11 10:35:00+00:00
# ❌ No opportunity at 2025-06-11 10:36:00+00:00
# ❌ No opportunity at 2025-06-11 10:37:00+00:00
# ❌ No opportunity at 2025-06-11 10:38:00+00:00
# ❌ No opportunity at 2025-06-11 10:39:00+00:00
# ❌ No opportunity at 2025-06-11 10:40:00+00:00
# ❌ No opportunity at 2025-06-11 10:41:00+00:00
# ❌ No opportunity at 2025-06-11 10:42:00+00:00
# ❌ No opportunity at 2025-06-11 10:43:00+00:00
# ❌ No opportunity at 2025-06-11 10:44:00+00:00
# ❌ No opportunity at 2025-06-11 10:45:00+00:00
# ❌ No opportunity at 2025-06-11 10:46:00+00:00
# ❌ No opportunity at 2025-06-11 10:47:00+00:00
# ❌ No opportunity at 2025-06-11 10:48:00+00:00
# ❌ No opportunity at 2025-06-11 10:49:00+00:00
# ❌ No opportunity at 2025-06-11 10:50:00+00:00
# ❌ No opportunity at 2025-06-11 10:51:00+00:00
# ❌ No opportunity at 2025-06-11 10:52:00+00:00
# ❌ No opportunity at 2025-06-11 10:53:00+00:00
# ❌ No opportunity at 2025-06-11 10:54:00+00:00
# ❌ No opportunity at 2025-06-11 10:55:00+00:00
# ❌ No opportunity at 2025-06-11 10:56:00+00:00
# ❌ No opportunity at 2025-06-11 10:57:00+00:00
# ❌ No opportunity at 2025-06-11 10:58:00+00:00
# ❌ No opportunity at 2025-06-11 10:59:00+00:00
# ❌ No opportunity at 2025-06-11 11:00:00+00:00
# ❌ No opportunity at 2025-06-11 11:01:00+00:00
# ❌ No opportunity at 2025-06-11 11:02:00+00:00
# ❌ No opportunity at 2025-06-11 11:03:00+00:00
# ❌ No opportunity at 2025-06-11 11:04:00+00:00
# ❌ No opportunity at 2025-06-11 11:05:00+00:00
# ❌ No opportunity at 2025-06-11 11:06:00+00:00
# ❌ No opportunity at 2025-06-11 11:07:00+00:00
# ❌ No opportunity at 2025-06-11 11:08:00+00:00
# ❌ No opportunity at 2025-06-11 11:09:00+00:00
# ❌ No opportunity at 2025-06-11 11:10:00+00:00
# ❌ No opportunity at 2025-06-11 11:11:00+00:00
# ❌ No opportunity at 2025-06-11 11:12:00+00:00
# ❌ No opportunity at 2025-06-11 11:13:00+00:00
# ❌ No opportunity at 2025-06-11 11:14:00+00:00
# ❌ No opportunity at 2025-06-11 11:15:00+00:00
# ❌ No opportunity at 2025-06-11 11:16:00+00:00
# ❌ No opportunity at 2025-06-11 11:17:00+00:00
# ❌ No opportunity at 2025-06-11 11:18:00+00:00
# ❌ No opportunity at 2025-06-11 11:19:00+00:00
# ❌ No opportunity at 2025-06-11 11:20:00+00:00
# ❌ No opportunity at 2025-06-11 11:21:00+00:00
# ❌ No opportunity at 2025-06-11 11:22:00+00:00
# ❌ No opportunity at 2025-06-11 11:23:00+00:00
# ❌ No opportunity at 2025-06-11 11:24:00+00:00
# ❌ No opportunity at 2025-06-11 11:25:00+00:00
# ❌ No opportunity at 2025-06-11 11:26:00+00:00
# ❌ No opportunity at 2025-06-11 11:27:00+00:00
# ❌ No opportunity at 2025-06-11 11:28:00+00:00
# ❌ No opportunity at 2025-06-11 11:29:00+00:00
# ❌ No opportunity at 2025-06-11 11:30:00+00:00
# ❌ No opportunity at 2025-06-11 11:31:00+00:00
# ❌ No opportunity at 2025-06-11 11:32:00+00:00
# ❌ No opportunity at 2025-06-11 11:33:00+00:00
# ❌ No opportunity at 2025-06-11 11:34:00+00:00
# ❌ No opportunity at 2025-06-11 11:35:00+00:00
# ❌ No opportunity at 2025-06-11 11:36:00+00:00
# ❌ No opportunity at 2025-06-11 11:37:00+00:00
# ❌ No opportunity at 2025-06-11 11:38:00+00:00
# ❌ No opportunity at 2025-06-11 11:39:00+00:00
# ❌ No opportunity at 2025-06-11 11:40:00+00:00
# ❌ No opportunity at 2025-06-11 11:41:00+00:00
# ❌ No opportunity at 2025-06-11 11:42:00+00:00
# ❌ No opportunity at 2025-06-11 11:43:00+00:00
# ❌ No opportunity at 2025-06-11 11:44:00+00:00
# ❌ No opportunity at 2025-06-11 11:45:00+00:00
# ❌ No opportunity at 2025-06-11 11:46:00+00:00
# ❌ No opportunity at 2025-06-11 11:47:00+00:00
# ❌ No opportunity at 2025-06-11 11:48:00+00:00
# ❌ No opportunity at 2025-06-11 11:49:00+00:00
# ❌ No opportunity at 2025-06-11 11:50:00+00:00
# ❌ No opportunity at 2025-06-11 11:51:00+00:00
# ❌ No opportunity at 2025-06-11 11:52:00+00:00
# ❌ No opportunity at 2025-06-11 11:53:00+00:00
# ❌ No opportunity at 2025-06-11 11:54:00+00:00
# ❌ No opportunity at 2025-06-11 11:55:00+00:00
# ❌ No opportunity at 2025-06-11 11:56:00+00:00
# ❌ No opportunity at 2025-06-11 11:57:00+00:00
# ❌ No opportunity at 2025-06-11 11:58:00+00:00
# ❌ No opportunity at 2025-06-11 11:59:00+00:00
# ❌ No opportunity at 2025-06-11 12:00:00+00:00
# ❌ No opportunity at 2025-06-11 12:01:00+00:00
# ❌ No opportunity at 2025-06-11 12:02:00+00:00
# ❌ No opportunity at 2025-06-11 12:03:00+00:00
# ❌ No opportunity at 2025-06-11 12:04:00+00:00
# ❌ No opportunity at 2025-06-11 12:05:00+00:00
# ❌ No opportunity at 2025-06-11 12:06:00+00:00
# ❌ No opportunity at 2025-06-11 12:07:00+00:00
# ❌ No opportunity at 2025-06-11 12:08:00+00:00
# ❌ No opportunity at 2025-06-11 12:09:00+00:00
# ❌ No opportunity at 2025-06-11 12:10:00+00:00
# ❌ No opportunity at 2025-06-11 12:11:00+00:00
# ❌ No opportunity at 2025-06-11 12:12:00+00:00
# ❌ No opportunity at 2025-06-11 12:13:00+00:00
# ❌ No opportunity at 2025-06-11 12:14:00+00:00
# ❌ No opportunity at 2025-06-11 12:15:00+00:00
# ❌ No opportunity at 2025-06-11 12:16:00+00:00
# ❌ No opportunity at 2025-06-11 12:17:00+00:00
# ❌ No opportunity at 2025-06-11 12:18:00+00:00
# ❌ No opportunity at 2025-06-11 12:19:00+00:00
# ❌ No opportunity at 2025-06-11 12:20:00+00:00
# ❌ No opportunity at 2025-06-11 12:21:00+00:00
# ❌ No opportunity at 2025-06-11 12:22:00+00:00
# ❌ No opportunity at 2025-06-11 12:23:00+00:00
# ❌ No opportunity at 2025-06-11 12:24:00+00:00
# ❌ No opportunity at 2025-06-11 12:25:00+00:00
# ❌ No opportunity at 2025-06-11 12:26:00+00:00
# ❌ No opportunity at 2025-06-11 12:27:00+00:00
# ❌ No opportunity at 2025-06-11 12:28:00+00:00
# ❌ No opportunity at 2025-06-11 12:29:00+00:00
# ❌ No opportunity at 2025-06-11 12:30:00+00:00
# ❌ No opportunity at 2025-06-11 12:31:00+00:00
# ❌ No opportunity at 2025-06-11 12:32:00+00:00
# ❌ No opportunity at 2025-06-11 12:33:00+00:00
# ❌ No opportunity at 2025-06-11 12:34:00+00:00
# ❌ No opportunity at 2025-06-11 12:35:00+00:00
# ❌ No opportunity at 2025-06-11 12:36:00+00:00
# ❌ No opportunity at 2025-06-11 12:37:00+00:00
# ❌ No opportunity at 2025-06-11 12:38:00+00:00
# ❌ No opportunity at 2025-06-11 12:39:00+00:00
# ❌ No opportunity at 2025-06-11 12:40:00+00:00
# ❌ No opportunity at 2025-06-11 12:41:00+00:00
# ❌ No opportunity at 2025-06-11 12:42:00+00:00
# ❌ No opportunity at 2025-06-11 12:43:00+00:00
# ❌ No opportunity at 2025-06-11 12:44:00+00:00
# ❌ No opportunity at 2025-06-11 12:45:00+00:00
# ❌ No opportunity at 2025-06-11 12:46:00+00:00
# ❌ No opportunity at 2025-06-11 12:47:00+00:00
# ❌ No opportunity at 2025-06-11 12:48:00+00:00
# ❌ No opportunity at 2025-06-11 12:49:00+00:00
# ❌ No opportunity at 2025-06-11 12:50:00+00:00
# ❌ No opportunity at 2025-06-11 12:51:00+00:00
# ❌ No opportunity at 2025-06-11 12:52:00+00:00
# ❌ No opportunity at 2025-06-11 12:53:00+00:00
# ❌ No opportunity at 2025-06-11 12:54:00+00:00
# ❌ No opportunity at 2025-06-11 12:55:00+00:00
# ❌ No opportunity at 2025-06-11 12:56:00+00:00
# ❌ No opportunity at 2025-06-11 12:57:00+00:00
# ❌ No opportunity at 2025-06-11 12:58:00+00:00
# ❌ No opportunity at 2025-06-11 12:59:00+00:00
# ❌ No opportunity at 2025-06-11 13:00:00+00:00
# ❌ No opportunity at 2025-06-11 13:01:00+00:00
# ❌ No opportunity at 2025-06-11 13:02:00+00:00
# ❌ No opportunity at 2025-06-11 13:03:00+00:00
# ❌ No opportunity at 2025-06-11 13:04:00+00:00
# ❌ No opportunity at 2025-06-11 13:05:00+00:00
# ❌ No opportunity at 2025-06-11 13:06:00+00:00
# ❌ No opportunity at 2025-06-11 13:07:00+00:00
# ❌ No opportunity at 2025-06-11 13:08:00+00:00
# ❌ No opportunity at 2025-06-11 13:09:00+00:00
# ❌ No opportunity at 2025-06-11 13:10:00+00:00
# ❌ No opportunity at 2025-06-11 13:11:00+00:00
# ❌ No opportunity at 2025-06-11 13:12:00+00:00
# ❌ No opportunity at 2025-06-11 13:13:00+00:00
# ❌ No opportunity at 2025-06-11 13:14:00+00:00
# ❌ No opportunity at 2025-06-11 13:15:00+00:00
# ❌ No opportunity at 2025-06-11 13:16:00+00:00
# ❌ No opportunity at 2025-06-11 13:17:00+00:00
# ❌ No opportunity at 2025-06-11 13:18:00+00:00
# ❌ No opportunity at 2025-06-11 13:19:00+00:00
# ❌ No opportunity at 2025-06-11 13:20:00+00:00
# ❌ No opportunity at 2025-06-11 13:21:00+00:00
# ❌ No opportunity at 2025-06-11 13:22:00+00:00
# ❌ No opportunity at 2025-06-11 13:23:00+00:00
# ❌ No opportunity at 2025-06-11 13:24:00+00:00
# ❌ No opportunity at 2025-06-11 13:25:00+00:00
# ❌ No opportunity at 2025-06-11 13:26:00+00:00
# ❌ No opportunity at 2025-06-11 13:27:00+00:00
# ❌ No opportunity at 2025-06-11 13:28:00+00:00
# ❌ No opportunity at 2025-06-11 13:29:00+00:00
# ❌ No opportunity at 2025-06-11 13:30:00+00:00
# ❌ No opportunity at 2025-06-11 13:31:00+00:00
# ❌ No opportunity at 2025-06-11 13:32:00+00:00
# ❌ No opportunity at 2025-06-11 13:33:00+00:00
# ❌ No opportunity at 2025-06-11 13:34:00+00:00
# ❌ No opportunity at 2025-06-11 13:35:00+00:00
# ❌ No opportunity at 2025-06-11 13:36:00+00:00
# ❌ No opportunity at 2025-06-11 13:37:00+00:00
# ❌ No opportunity at 2025-06-11 13:38:00+00:00
# ❌ No opportunity at 2025-06-11 13:39:00+00:00
# ❌ No opportunity at 2025-06-11 13:40:00+00:00
# ❌ No opportunity at 2025-06-11 13:41:00+00:00
# ❌ No opportunity at 2025-06-11 13:42:00+00:00
# ❌ No opportunity at 2025-06-11 13:43:00+00:00
# ❌ No opportunity at 2025-06-11 13:44:00+00:00
# ❌ No opportunity at 2025-06-11 13:45:00+00:00
# ❌ No opportunity at 2025-06-11 13:46:00+00:00
# ❌ No opportunity at 2025-06-11 13:47:00+00:00
# ❌ No opportunity at 2025-06-11 13:48:00+00:00
# ❌ No opportunity at 2025-06-11 13:49:00+00:00
# ❌ No opportunity at 2025-06-11 13:50:00+00:00
# ❌ No opportunity at 2025-06-11 13:51:00+00:00
# ❌ No opportunity at 2025-06-11 13:52:00+00:00
# ❌ No opportunity at 2025-06-11 13:53:00+00:00
# ❌ No opportunity at 2025-06-11 13:54:00+00:00
# ❌ No opportunity at 2025-06-11 13:55:00+00:00
# ❌ No opportunity at 2025-06-11 13:56:00+00:00
# ❌ No opportunity at 2025-06-11 13:57:00+00:00
# ❌ No opportunity at 2025-06-11 13:58:00+00:00
# ❌ No opportunity at 2025-06-11 13:59:00+00:00
# ❌ No opportunity at 2025-06-11 14:00:00+00:00
# ❌ No opportunity at 2025-06-11 14:01:00+00:00
# ❌ No opportunity at 2025-06-11 14:02:00+00:00
# ❌ No opportunity at 2025-06-11 14:03:00+00:00
# ❌ No opportunity at 2025-06-11 14:04:00+00:00
# ❌ No opportunity at 2025-06-11 14:05:00+00:00
# ❌ No opportunity at 2025-06-11 14:06:00+00:00
# ❌ No opportunity at 2025-06-11 14:07:00+00:00
# ❌ No opportunity at 2025-06-11 14:08:00+00:00
# ❌ No opportunity at 2025-06-11 14:09:00+00:00
# ❌ No opportunity at 2025-06-11 14:10:00+00:00
# ❌ No opportunity at 2025-06-11 14:11:00+00:00
# ❌ No opportunity at 2025-06-11 14:12:00+00:00
# ❌ No opportunity at 2025-06-11 14:13:00+00:00
# ❌ No opportunity at 2025-06-11 14:14:00+00:00
# ❌ No opportunity at 2025-06-11 14:15:00+00:00
# ❌ No opportunity at 2025-06-11 14:16:00+00:00
# ❌ No opportunity at 2025-06-11 14:17:00+00:00
# ❌ No opportunity at 2025-06-11 14:18:00+00:00
# ❌ No opportunity at 2025-06-11 14:19:00+00:00
# ❌ No opportunity at 2025-06-11 14:20:00+00:00
# ❌ No opportunity at 2025-06-11 14:21:00+00:00
# ❌ No opportunity at 2025-06-11 14:22:00+00:00
# ❌ No opportunity at 2025-06-11 14:23:00+00:00
# ❌ No opportunity at 2025-06-11 14:24:00+00:00
# ❌ No opportunity at 2025-06-11 14:25:00+00:00
# ❌ No opportunity at 2025-06-11 14:26:00+00:00
# ❌ No opportunity at 2025-06-11 14:27:00+00:00
# ❌ No opportunity at 2025-06-11 14:28:00+00:00
# ❌ No opportunity at 2025-06-11 14:29:00+00:00
# ❌ No opportunity at 2025-06-11 14:30:00+00:00
# ❌ No opportunity at 2025-06-11 14:31:00+00:00
# ❌ No opportunity at 2025-06-11 14:32:00+00:00
# ❌ No opportunity at 2025-06-11 14:33:00+00:00
# ❌ No opportunity at 2025-06-11 14:34:00+00:00
# ❌ No opportunity at 2025-06-11 14:35:00+00:00
# ❌ No opportunity at 2025-06-11 14:36:00+00:00
# ❌ No opportunity at 2025-06-11 14:37:00+00:00
# ❌ No opportunity at 2025-06-11 14:38:00+00:00
# ❌ No opportunity at 2025-06-11 14:39:00+00:00
# ❌ No opportunity at 2025-06-11 14:40:00+00:00
# ❌ No opportunity at 2025-06-11 14:41:00+00:00
# ❌ No opportunity at 2025-06-11 14:42:00+00:00
# ❌ No opportunity at 2025-06-11 14:43:00+00:00
# ❌ No opportunity at 2025-06-11 14:44:00+00:00
# ❌ No opportunity at 2025-06-11 14:45:00+00:00
# ❌ No opportunity at 2025-06-11 14:46:00+00:00
# ❌ No opportunity at 2025-06-11 14:47:00+00:00
# ❌ No opportunity at 2025-06-11 14:48:00+00:00
# ❌ No opportunity at 2025-06-11 14:49:00+00:00
# ❌ No opportunity at 2025-06-11 14:50:00+00:00
# ❌ No opportunity at 2025-06-11 14:51:00+00:00
# ❌ No opportunity at 2025-06-11 14:52:00+00:00
# ❌ No opportunity at 2025-06-11 14:53:00+00:00
# ❌ No opportunity at 2025-06-11 14:54:00+00:00
# ❌ No opportunity at 2025-06-11 14:55:00+00:00
# ...
# ❌ No opportunity at 2025-06-16 03:43:00+00:00
# ❌ No opportunity at 2025-06-16 03:44:00+00:00
# ❌ No opportunity at 2025-06-16 03:45:00+00:00
# ❌ No opportunity at 2025-06-16 03:46:00+00:00
# ❌ No opportunity at 2025-06-16 03:47:00+00:00
# ❌ No opportunity at 2025-06-16 03:48:00+00:00
# ❌ No opportunity at 2025-06-16 03:49:00+00:00
# ❌ No opportunity at 2025-06-16 03:50:00+00:00
# ❌ No opportunity at 2025-06-16 03:51:00+00:00
# ❌ No opportunity at 2025-06-16 03:52:00+00:00
# ❌ No opportunity at 2025-06-16 03:53:00+00:00
# ❌ No opportunity at 2025-06-16 03:54:00+00:00
# ❌ No opportunity at 2025-06-16 03:55:00+00:00
# ❌ No opportunity at 2025-06-16 03:56:00+00:00
# ❌ No opportunity at 2025-06-16 03:57:00+00:00
# ❌ No opportunity at 2025-06-16 03:58:00+00:00
# ❌ No opportunity at 2025-06-16 03:59:00+00:00
# ❌ No opportunity at 2025-06-16 04:00:00+00:00
# ❌ No opportunity at 2025-06-16 04:01:00+00:00
# ❌ No opportunity at 2025-06-16 04:02:00+00:00
# ❌ No opportunity at 2025-06-16 04:03:00+00:00
# ❌ No opportunity at 2025-06-16 04:04:00+00:00
# ❌ No opportunity at 2025-06-16 04:05:00+00:00
# ❌ No opportunity at 2025-06-16 04:06:00+00:00
# ❌ No opportunity at 2025-06-16 04:07:00+00:00
# ❌ No opportunity at 2025-06-16 04:08:00+00:00
# ❌ No opportunity at 2025-06-16 04:09:00+00:00
# ❌ No opportunity at 2025-06-16 04:10:00+00:00
# ❌ No opportunity at 2025-06-16 04:11:00+00:00
# ❌ No opportunity at 2025-06-16 04:12:00+00:00
# ❌ No opportunity at 2025-06-16 04:13:00+00:00
# ❌ No opportunity at 2025-06-16 04:14:00+00:00
# ❌ No opportunity at 2025-06-16 04:15:00+00:00
# ❌ No opportunity at 2025-06-16 04:16:00+00:00
# ❌ No opportunity at 2025-06-16 04:17:00+00:00
# ❌ No opportunity at 2025-06-16 04:18:00+00:00
# ❌ No opportunity at 2025-06-16 04:19:00+00:00
# ❌ No opportunity at 2025-06-16 04:20:00+00:00
# ❌ No opportunity at 2025-06-16 04:21:00+00:00
# ❌ No opportunity at 2025-06-16 04:22:00+00:00
# ❌ No opportunity at 2025-06-16 04:23:00+00:00
# ❌ No opportunity at 2025-06-16 04:24:00+00:00
# ❌ No opportunity at 2025-06-16 04:25:00+00:00
# ❌ No opportunity at 2025-06-16 04:26:00+00:00
# ❌ No opportunity at 2025-06-16 04:27:00+00:00
# ❌ No opportunity at 2025-06-16 04:28:00+00:00
# ❌ No opportunity at 2025-06-16 04:29:00+00:00
# ❌ No opportunity at 2025-06-16 04:30:00+00:00
# ❌ No opportunity at 2025-06-16 04:31:00+00:00
# ❌ No opportunity at 2025-06-16 04:32:00+00:00
# ❌ No opportunity at 2025-06-16 04:33:00+00:00
# ❌ No opportunity at 2025-06-16 04:34:00+00:00
# ❌ No opportunity at 2025-06-16 04:35:00+00:00
# ❌ No opportunity at 2025-06-16 04:36:00+00:00
# ❌ No opportunity at 2025-06-16 04:37:00+00:00
# ❌ No opportunity at 2025-06-16 04:38:00+00:00
# ❌ No opportunity at 2025-06-16 04:39:00+00:00
# ❌ No opportunity at 2025-06-16 04:40:00+00:00
# ❌ No opportunity at 2025-06-16 04:41:00+00:00
# ❌ No opportunity at 2025-06-16 04:42:00+00:00
# ❌ No opportunity at 2025-06-16 04:43:00+00:00
# ❌ No opportunity at 2025-06-16 04:44:00+00:00
# ❌ No opportunity at 2025-06-16 04:45:00+00:00
# ❌ No opportunity at 2025-06-16 04:46:00+00:00
# ❌ No opportunity at 2025-06-16 04:47:00+00:00
# ❌ No opportunity at 2025-06-16 04:48:00+00:00
# ❌ No opportunity at 2025-06-16 04:49:00+00:00
# ❌ No opportunity at 2025-06-16 04:50:00+00:00
# ❌ No opportunity at 2025-06-16 04:51:00+00:00
# ❌ No opportunity at 2025-06-16 04:52:00+00:00
# ❌ No opportunity at 2025-06-16 04:53:00+00:00
# ❌ No opportunity at 2025-06-16 04:54:00+00:00
# ❌ No opportunity at 2025-06-16 04:55:00+00:00
# ❌ No opportunity at 2025-06-16 04:56:00+00:00
# ❌ No opportunity at 2025-06-16 04:57:00+00:00
# ❌ No opportunity at 2025-06-16 04:58:00+00:00
# ❌ No opportunity at 2025-06-16 04:59:00+00:00
# ❌ No opportunity at 2025-06-16 05:00:00+00:00
# ❌ No opportunity at 2025-06-16 05:01:00+00:00
# ❌ No opportunity at 2025-06-16 05:02:00+00:00
# ❌ No opportunity at 2025-06-16 05:03:00+00:00
# ❌ No opportunity at 2025-06-16 05:04:00+00:00
# ❌ No opportunity at 2025-06-16 05:05:00+00:00
# ❌ No opportunity at 2025-06-16 05:06:00+00:00
# ❌ No opportunity at 2025-06-16 05:07:00+00:00
# ❌ No opportunity at 2025-06-16 05:08:00+00:00
# ❌ No opportunity at 2025-06-16 05:09:00+00:00
# ❌ No opportunity at 2025-06-16 05:10:00+00:00
# ❌ No opportunity at 2025-06-16 05:11:00+00:00
# ❌ No opportunity at 2025-06-16 05:12:00+00:00
# ❌ No opportunity at 2025-06-16 05:13:00+00:00
# ❌ No opportunity at 2025-06-16 05:14:00+00:00
# ❌ No opportunity at 2025-06-16 05:15:00+00:00
# ❌ No opportunity at 2025-06-16 05:16:00+00:00
# ❌ No opportunity at 2025-06-16 05:17:00+00:00
# ❌ No opportunity at 2025-06-16 05:18:00+00:00
# ❌ No opportunity at 2025-06-16 05:19:00+00:00
# ❌ No opportunity at 2025-06-16 05:20:00+00:00
# ❌ No opportunity at 2025-06-16 05:21:00+00:00
# ❌ No opportunity at 2025-06-16 05:22:00+00:00
# ❌ No opportunity at 2025-06-16 05:23:00+00:00
# ❌ No opportunity at 2025-06-16 05:24:00+00:00
# ❌ No opportunity at 2025-06-16 05:25:00+00:00
# ❌ No opportunity at 2025-06-16 05:26:00+00:00
# ❌ No opportunity at 2025-06-16 05:27:00+00:00
# ❌ No opportunity at 2025-06-16 05:28:00+00:00
# ❌ No opportunity at 2025-06-16 05:29:00+00:00
# ❌ No opportunity at 2025-06-16 05:30:00+00:00
# ❌ No opportunity at 2025-06-16 05:31:00+00:00
# ❌ No opportunity at 2025-06-16 05:32:00+00:00
# ❌ No opportunity at 2025-06-16 05:33:00+00:00
# ❌ No opportunity at 2025-06-16 05:34:00+00:00
# ❌ No opportunity at 2025-06-16 05:35:00+00:00
# ❌ No opportunity at 2025-06-16 05:36:00+00:00
# ❌ No opportunity at 2025-06-16 05:37:00+00:00
# ❌ No opportunity at 2025-06-16 05:38:00+00:00
# ❌ No opportunity at 2025-06-16 05:39:00+00:00
# ❌ No opportunity at 2025-06-16 05:40:00+00:00
# ❌ No opportunity at 2025-06-16 05:41:00+00:00
# ❌ No opportunity at 2025-06-16 05:42:00+00:00
# ❌ No opportunity at 2025-06-16 05:43:00+00:00
# ❌ No opportunity at 2025-06-16 05:44:00+00:00
# ❌ No opportunity at 2025-06-16 05:45:00+00:00
# ❌ No opportunity at 2025-06-16 05:46:00+00:00
# ❌ No opportunity at 2025-06-16 05:47:00+00:00
# ❌ No opportunity at 2025-06-16 05:48:00+00:00
# ❌ No opportunity at 2025-06-16 05:49:00+00:00
# ❌ No opportunity at 2025-06-16 05:50:00+00:00
# ❌ No opportunity at 2025-06-16 05:51:00+00:00
# ❌ No opportunity at 2025-06-16 05:52:00+00:00
# ❌ No opportunity at 2025-06-16 05:53:00+00:00
# ❌ No opportunity at 2025-06-16 05:54:00+00:00
# ❌ No opportunity at 2025-06-16 05:55:00+00:00
# ❌ No opportunity at 2025-06-16 05:56:00+00:00
# ❌ No opportunity at 2025-06-16 05:57:00+00:00
# ❌ No opportunity at 2025-06-16 05:58:00+00:00
# ❌ No opportunity at 2025-06-16 05:59:00+00:00
# ❌ No opportunity at 2025-06-16 06:00:00+00:00
# ❌ No opportunity at 2025-06-16 06:01:00+00:00
# ❌ No opportunity at 2025-06-16 06:02:00+00:00
# ❌ No opportunity at 2025-06-16 06:03:00+00:00
# ❌ No opportunity at 2025-06-16 06:04:00+00:00
# ❌ No opportunity at 2025-06-16 06:05:00+00:00
# ❌ No opportunity at 2025-06-16 06:06:00+00:00
# ❌ No opportunity at 2025-06-16 06:07:00+00:00
# ❌ No opportunity at 2025-06-16 06:08:00+00:00
# ❌ No opportunity at 2025-06-16 06:09:00+00:00
# ❌ No opportunity at 2025-06-16 06:10:00+00:00
# ❌ No opportunity at 2025-06-16 06:11:00+00:00
# ❌ No opportunity at 2025-06-16 06:12:00+00:00
# ❌ No opportunity at 2025-06-16 06:13:00+00:00
# ❌ No opportunity at 2025-06-16 06:14:00+00:00
# ❌ No opportunity at 2025-06-16 06:15:00+00:00
# ❌ No opportunity at 2025-06-16 06:16:00+00:00
# ❌ No opportunity at 2025-06-16 06:17:00+00:00
# ❌ No opportunity at 2025-06-16 06:18:00+00:00
# ❌ No opportunity at 2025-06-16 06:19:00+00:00
# ❌ No opportunity at 2025-06-16 06:20:00+00:00
# ❌ No opportunity at 2025-06-16 06:21:00+00:00
# ❌ No opportunity at 2025-06-16 06:22:00+00:00
# ❌ No opportunity at 2025-06-16 06:23:00+00:00
# ❌ No opportunity at 2025-06-16 06:24:00+00:00
# ❌ No opportunity at 2025-06-16 06:25:00+00:00
# ❌ No opportunity at 2025-06-16 06:26:00+00:00
# ❌ No opportunity at 2025-06-16 06:27:00+00:00
# ❌ No opportunity at 2025-06-16 06:28:00+00:00
# ❌ No opportunity at 2025-06-16 06:29:00+00:00
# ❌ No opportunity at 2025-06-16 06:30:00+00:00
# ❌ No opportunity at 2025-06-16 06:31:00+00:00
# ❌ No opportunity at 2025-06-16 06:32:00+00:00
# ❌ No opportunity at 2025-06-16 06:33:00+00:00
# ❌ No opportunity at 2025-06-16 06:34:00+00:00
# ❌ No opportunity at 2025-06-16 06:35:00+00:00
# ❌ No opportunity at 2025-06-16 06:36:00+00:00
# ❌ No opportunity at 2025-06-16 06:37:00+00:00
# ❌ No opportunity at 2025-06-16 06:38:00+00:00
# ❌ No opportunity at 2025-06-16 06:39:00+00:00
# ❌ No opportunity at 2025-06-16 06:40:00+00:00
# ❌ No opportunity at 2025-06-16 06:41:00+00:00
# ❌ No opportunity at 2025-06-16 06:42:00+00:00
# ❌ No opportunity at 2025-06-16 06:43:00+00:00
# ❌ No opportunity at 2025-06-16 06:44:00+00:00
# ❌ No opportunity at 2025-06-16 06:45:00+00:00
# ❌ No opportunity at 2025-06-16 06:46:00+00:00
# ❌ No opportunity at 2025-06-16 06:47:00+00:00
# ❌ No opportunity at 2025-06-16 06:48:00+00:00
# ❌ No opportunity at 2025-06-16 06:49:00+00:00
# ❌ No opportunity at 2025-06-16 06:50:00+00:00
# ❌ No opportunity at 2025-06-16 06:51:00+00:00
# ❌ No opportunity at 2025-06-16 06:52:00+00:00
# ❌ No opportunity at 2025-06-16 06:53:00+00:00
# ❌ No opportunity at 2025-06-16 06:54:00+00:00
# ❌ No opportunity at 2025-06-16 06:55:00+00:00
# ❌ No opportunity at 2025-06-16 06:56:00+00:00
# ❌ No opportunity at 2025-06-16 06:57:00+00:00
# ❌ No opportunity at 2025-06-16 06:58:00+00:00
# ❌ No opportunity at 2025-06-16 06:59:00+00:00
# ❌ No opportunity at 2025-06-16 07:00:00+00:00
# ❌ No opportunity at 2025-06-16 07:01:00+00:00
# ❌ No opportunity at 2025-06-16 07:02:00+00:00
# ❌ No opportunity at 2025-06-16 07:03:00+00:00
# ❌ No opportunity at 2025-06-16 07:04:00+00:00
# ❌ No opportunity at 2025-06-16 07:05:00+00:00
# ❌ No opportunity at 2025-06-16 07:06:00+00:00
# ❌ No opportunity at 2025-06-16 07:07:00+00:00
# ❌ No opportunity at 2025-06-16 07:08:00+00:00
# ❌ No opportunity at 2025-06-16 07:09:00+00:00
# ❌ No opportunity at 2025-06-16 07:10:00+00:00
# ❌ No opportunity at 2025-06-16 07:11:00+00:00
# ❌ No opportunity at 2025-06-16 07:12:00+00:00
# ❌ No opportunity at 2025-06-16 07:13:00+00:00
# ❌ No opportunity at 2025-06-16 07:14:00+00:00
# ❌ No opportunity at 2025-06-16 07:15:00+00:00
# ❌ No opportunity at 2025-06-16 07:16:00+00:00
# ❌ No opportunity at 2025-06-16 07:17:00+00:00
# ❌ No opportunity at 2025-06-16 07:18:00+00:00
# ❌ No opportunity at 2025-06-16 07:19:00+00:00
# ❌ No opportunity at 2025-06-16 07:20:00+00:00
# ❌ No opportunity at 2025-06-16 07:21:00+00:00
# ❌ No opportunity at 2025-06-16 07:22:00+00:00
# ❌ No opportunity at 2025-06-16 07:23:00+00:00
# ❌ No opportunity at 2025-06-16 07:24:00+00:00
# ❌ No opportunity at 2025-06-16 07:25:00+00:00
# ❌ No opportunity at 2025-06-16 07:26:00+00:00
# ❌ No opportunity at 2025-06-16 07:27:00+00:00
# ❌ No opportunity at 2025-06-16 07:28:00+00:00
# ❌ No opportunity at 2025-06-16 07:29:00+00:00
# ❌ No opportunity at 2025-06-16 07:30:00+00:00
# ❌ No opportunity at 2025-06-16 07:31:00+00:00
# ❌ No opportunity at 2025-06-16 07:32:00+00:00
# ❌ No opportunity at 2025-06-16 07:33:00+00:00
# ❌ No opportunity at 2025-06-16 07:34:00+00:00
# ❌ No opportunity at 2025-06-16 07:35:00+00:00
# ❌ No opportunity at 2025-06-16 07:36:00+00:00
# ❌ No opportunity at 2025-06-16 07:37:00+00:00
# ❌ No opportunity at 2025-06-16 07:38:00+00:00
# ❌ No opportunity at 2025-06-16 07:39:00+00:00
# ❌ No opportunity at 2025-06-16 07:40:00+00:00
# ❌ No opportunity at 2025-06-16 07:41:00+00:00
# ❌ No opportunity at 2025-06-16 07:42:00+00:00
# ❌ No opportunity at 2025-06-16 07:43:00+00:00
# ❌ No opportunity at 2025-06-16 07:44:00+00:00
# ❌ No opportunity at 2025-06-16 07:45:00+00:00
# ❌ No opportunity at 2025-06-16 07:46:00+00:00
# ❌ No opportunity at 2025-06-16 07:47:00+00:00
# ❌ No opportunity at 2025-06-16 07:48:00+00:00
# ❌ No opportunity at 2025-06-16 07:49:00+00:00
# ❌ No opportunity at 2025-06-16 07:50:00+00:00
# ❌ No opportunity at 2025-06-16 07:51:00+00:00
# ❌ No opportunity at 2025-06-16 07:52:00+00:00
# ❌ No opportunity at 2025-06-16 07:53:00+00:00
# ❌ No opportunity at 2025-06-16 07:54:00+00:00
# ❌ No opportunity at 2025-06-16 07:55:00+00:00
# ❌ No opportunity at 2025-06-16 07:56:00+00:00
# ❌ No opportunity at 2025-06-16 07:57:00+00:00
# ❌ No opportunity at 2025-06-16 07:58:00+00:00
# ❌ No opportunity at 2025-06-16 07:59:00+00:00
# ❌ No opportunity at 2025-06-16 08:00:00+00:00
# ❌ No opportunity at 2025-06-16 08:01:00+00:00
# ❌ No opportunity at 2025-06-16 08:02:00+00:00
# ❌ No opportunity at 2025-06-16 08:03:00+00:00
# ❌ No opportunity at 2025-06-16 08:04:00+00:00
# ❌ No opportunity at 2025-06-16 08:05:00+00:00
# ❌ No opportunity at 2025-06-16 08:06:00+00:00
# ❌ No opportunity at 2025-06-16 08:07:00+00:00
# ❌ No opportunity at 2025-06-16 08:08:00+00:00
# ❌ No opportunity at 2025-06-16 08:09:00+00:00
# ❌ No opportunity at 2025-06-16 08:10:00+00:00
# ❌ No opportunity at 2025-06-16 08:11:00+00:00
# ❌ No opportunity at 2025-06-16 08:12:00+00:00
# ❌ No opportunity at 2025-06-16 08:13:00+00:00
# ❌ No opportunity at 2025-06-16 08:14:00+00:00
# ❌ No opportunity at 2025-06-16 08:15:00+00:00
# ❌ No opportunity at 2025-06-16 08:16:00+00:00
# ❌ No opportunity at 2025-06-16 08:17:00+00:00
# ❌ No opportunity at 2025-06-16 08:18:00+00:00
# ❌ No opportunity at 2025-06-16 08:19:00+00:00
# ❌ No opportunity at 2025-06-16 08:20:00+00:00
# ❌ No opportunity at 2025-06-16 08:21:00+00:00
# ❌ No opportunity at 2025-06-16 08:22:00+00:00
# ❌ No opportunity at 2025-06-16 08:23:00+00:00
# ❌ No opportunity at 2025-06-16 08:24:00+00:00
# ❌ No opportunity at 2025-06-16 08:25:00+00:00
# ❌ No opportunity at 2025-06-16 08:26:00+00:00
# ❌ No opportunity at 2025-06-16 08:27:00+00:00
# ❌ No opportunity at 2025-06-16 08:28:00+00:00
# ❌ No opportunity at 2025-06-16 08:29:00+00:00
# ❌ No opportunity at 2025-06-16 08:30:00+00:00
# ❌ No opportunity at 2025-06-16 08:31:00+00:00
# ❌ No opportunity at 2025-06-16 08:32:00+00:00
# ❌ No opportunity at 2025-06-16 08:33:00+00:00
# ❌ No opportunity at 2025-06-16 08:34:00+00:00
# ❌ No opportunity at 2025-06-16 08:35:00+00:00
# ❌ No opportunity at 2025-06-16 08:36:00+00:00
# ❌ No opportunity at 2025-06-16 08:37:00+00:00
# ❌ No opportunity at 2025-06-16 08:38:00+00:00
# ❌ No opportunity at 2025-06-16 08:39:00+00:00
# ❌ No opportunity at 2025-06-16 08:40:00+00:00
# ❌ No opportunity at 2025-06-16 08:41:00+00:00
# ❌ No opportunity at 2025-06-16 08:42:00+00:00
# ❌ No opportunity at 2025-06-16 08:43:00+00:00
# ❌ No opportunity at 2025-06-16 08:44:00+00:00
# ❌ No opportunity at 2025-06-16 08:45:00+00:00
# ❌ No opportunity at 2025-06-16 08:46:00+00:00
# ❌ No opportunity at 2025-06-16 08:47:00+00:00
# ❌ No opportunity at 2025-06-16 08:48:00+00:00
# ❌ No opportunity at 2025-06-16 08:49:00+00:00
# ❌ No opportunity at 2025-06-16 08:50:00+00:00
# ❌ No opportunity at 2025-06-16 08:51:00+00:00
# ❌ No opportunity at 2025-06-16 08:52:00+00:00
# ❌ No opportunity at 2025-06-16 08:53:00+00:00
# ❌ No opportunity at 2025-06-16 08:54:00+00:00
# ❌ No opportunity at 2025-06-16 08:55:00+00:00
# ❌ No opportunity at 2025-06-16 08:56:00+00:00
# ❌ No opportunity at 2025-06-16 08:57:00+00:00
# ❌ No opportunity at 2025-06-16 08:58:00+00:00
# ❌ No opportunity at 2025-06-16 08:59:00+00:00
# ❌ No opportunity at 2025-06-16 09:00:00+00:00
# ❌ No opportunity at 2025-06-16 09:01:00+00:00
# ❌ No opportunity at 2025-06-16 09:02:00+00:00
# ❌ No opportunity at 2025-06-16 09:03:00+00:00
# ❌ No opportunity at 2025-06-16 09:04:00+00:00
# ❌ No opportunity at 2025-06-16 09:05:00+00:00
# ❌ No opportunity at 2025-06-16 09:06:00+00:00
# ❌ No opportunity at 2025-06-16 09:07:00+00:00
# ❌ No opportunity at 2025-06-16 09:08:00+00:00
# ❌ No opportunity at 2025-06-16 09:09:00+00:00
# ❌ No opportunity at 2025-06-16 09:10:00+00:00
# ❌ No opportunity at 2025-06-16 09:11:00+00:00
# ❌ No opportunity at 2025-06-16 09:12:00+00:00
# ❌ No opportunity at 2025-06-16 09:13:00+00:00
# ❌ No opportunity at 2025-06-16 09:14:00+00:00
# ❌ No opportunity at 2025-06-16 09:15:00+00:00
# ❌ No opportunity at 2025-06-16 09:16:00+00:00
# ❌ No opportunity at 2025-06-16 09:17:00+00:00
# ❌ No opportunity at 2025-06-16 09:18:00+00:00
# ❌ No opportunity at 2025-06-16 09:19:00+00:00
# ❌ No opportunity at 2025-06-16 09:20:00+00:00
# ❌ No opportunity at 2025-06-16 09:21:00+00:00
# ❌ No opportunity at 2025-06-16 09:22:00+00:00
# ❌ No opportunity at 2025-06-16 09:23:00+00:00
# ❌ No opportunity at 2025-06-16 09:24:00+00:00
# ❌ No opportunity at 2025-06-16 09:25:00+00:00
# ❌ No opportunity at 2025-06-16 09:26:00+00:00
# ❌ No opportunity at 2025-06-16 09:27:00+00:00
# ❌ No opportunity at 2025-06-16 09:28:00+00:00
#
# 📈 Summary of Opportunities:
# None found.

# %%
# Import libraries
import pandas as pd
import numpy as np
from oandapyV20 import API
from oandapyV20.endpoints.instruments import InstrumentsCandles

# ===== YOUR CREDENTIALS () =====
ACCESS_TOKEN = "32a7ce5d62167ef2dda800802386d48a-496bae9b01506113e0a75dbac8e7a693"  # Replace with env var in production

# 1. Function to fetch historical data for one instrument
def fetch_forex_data(instrument="EUR_USD", granularity="M1", count=60):  # M1 = Monthly, 60 = 5 years of data
    client = API(access_token=ACCESS_TOKEN, environment="practice")

    params = {
        "granularity": granularity,
        "count": count
    }

    r = InstrumentsCandles(instrument=instrument, params=params)

    try:
        client.request(r)
    except Exception as e:
        raise ConnectionError(f"Failed to fetch data for {instrument}: {e}")

    data = []
    for candle in r.response['candles']:
        data.append({
            'datetime': candle['time'],
            'close': float(candle['mid']['c'])
        })

    df = pd.DataFrame(data)
    df['datetime'] = pd.to_datetime(df['datetime'])
    df.set_index('datetime', inplace=True)
    return df[['close']].rename(columns={'close': instrument})

# 2. Define triangles
def get_triangles():
    return [
        ["EUR", "USD", "GBP"],   # Uses EUR_USD, GBP_USD, GBP_EUR
        ["AUD", "USD", "NZD"],   # Uses AUD_USD, NZD_USD
        ["USD", "JPY", "EUR"],   # Uses USD_JPY, EUR_JPY
    ]

# 3. Detect arbitrage opportunity at a single timestamp
def detect_opportunity(triangle, row):
    c1, c2, c3 = triangle
    p1 = f"{c1}_{c2}"
    p2 = f"{c2}_{c3}"
    p3 = f"{c3}_{c1}"

    try:
        val = 1.0
        val *= row[p1]
        val *= row[p2]
        val *= row[p3]

        profit = val - 1.0
        return profit
    except KeyError:
        return None

# 4. Main backtest function
def run_triangular_arbitrage_backtest(pairs, granularity="M1", count=60):
    dfs = []
    print("📥 Fetching monthly historical data for:")
    for pair in pairs:
        print(f"  - {pair}")
        df = fetch_forex_data(pair, granularity, count)
        dfs.append(df)

    # Merge all into one DataFrame
    merged = pd.concat(dfs, axis=1)
    merged.dropna(inplace=True)
    merged.sort_index(inplace=True)

    print("\n📊 Merged Monthly DataFrame Sample:")
    print(merged.head())

    triangles = get_triangles()
    results = []

    print("\n🔍 Running monthly triangular arbitrage backtest...\n")
    for idx, row in merged.iterrows():
        found = False
        for triangle in triangles:
            profit = detect_opportunity(triangle, row)
            if profit is not None and profit > 0.0001:
                print(f"✅ Opportunity at {idx} | Triangle: {triangle} | Profit: {profit*100:.4f}%")
                results.append({
                    "timestamp": idx,
                    "triangle": str(triangle),
                    "profit_percent": round(profit * 100, 4)
                })
                found = True
        if not found:
            print(f"❌ No opportunity at {idx}")

    print("\n📈 Summary of Monthly Arbitrage Opportunities:")
    result_df = pd.DataFrame(results)
    if not result_df.empty:
        print(result_df.to_string(index=False))
    else:
        print("None found.")
    return result_df

# ===== RUN FULL BACKTEST =====
if __name__ == "__main__":
    # List of forex pairs needed for the triangles
    forex_pairs = [
        "EUR_USD", "GBP_USD", "GBP_CHF",
        "AUD_USD", "NZD_USD",
        "USD_JPY", "EUR_JPY"
    ]

    # Run the monthly backtest
    arbitrage_results = run_triangular_arbitrage_backtest(
        pairs=forex_pairs,
        granularity="M1",   # Monthly candles
        count=60            # Last 5 years (~60 months)
    )
# Out:
# 📥 Fetching monthly historical data for:
#   - EUR_USD
#   - GBP_USD
#   - GBP_CHF
#   - AUD_USD
#   - NZD_USD
#   - USD_JPY
#   - EUR_JPY
#
# 📊 Merged Monthly DataFrame Sample:
#                            EUR_USD  GBP_USD  GBP_CHF  AUD_USD  NZD_USD  \
# datetime
# 2025-06-16 08:49:00+00:00  1.15792  1.35787  1.10216  0.65108  0.60354
# 2025-06-16 08:50:00+00:00  1.15804  1.35810  1.10220  0.65130  0.60372
# 2025-06-16 08:51:00+00:00  1.15824  1.35817  1.10222  0.65131  0.60385
# 2025-06-16 08:52:00+00:00  1.15826  1.35819  1.10233  0.65145  0.60398
# 2025-06-16 08:53:00+00:00  1.15821  1.35800  1.10225  0.65148  0.60398
#
#                            USD_JPY  EUR_JPY
# datetime
# 2025-06-16 08:49:00+00:00  144.162  166.926
# 2025-06-16 08:50:00+00:00  144.109  166.881
# 2025-06-16 08:51:00+00:00  144.104  166.907
# 2025-06-16 08:52:00+00:00  144.104  166.908
# 2025-06-16 08:53:00+00:00  144.124  166.926
#
# 🔍 Running monthly triangular arbitrage backtest...
#
# ❌ No opportunity at 2025-06-16 08:49:00+00:00
# ❌ No opportunity at 2025-06-16 08:50:00+00:00
# ❌ No opportunity at 2025-06-16 08:51:00+00:00
# ❌ No opportunity at 2025-06-16 08:52:00+00:00
# ❌ No opportunity at 2025-06-16 08:53:00+00:00
# ❌ No opportunity at 2025-06-16 08:54:00+00:00
# ❌ No opportunity at 2025-06-16 08:55:00+00:00
# ❌ No opportunity at 2025-06-16 08:56:00+00:00
# ❌ No opportunity at 2025-06-16 08:57:00+00:00
# ❌ No opportunity at 2025-06-16 08:58:00+00:00
# ❌ No opportunity at 2025-06-16 08:59:00+00:00
# ❌ No opportunity at 2025-06-16 09:00:00+00:00
# ❌ No opportunity at 2025-06-16 09:01:00+00:00
# ❌ No opportunity at 2025-06-16 09:02:00+00:00
# ❌ No opportunity at 2025-06-16 09:03:00+00:00
# ❌ No opportunity at 2025-06-16 09:04:00+00:00
# ❌ No opportunity at 2025-06-16 09:05:00+00:00
# ❌ No opportunity at 2025-06-16 09:06:00+00:00
# ❌ No opportunity at 2025-06-16 09:07:00+00:00
# ❌ No opportunity at 2025-06-16 09:08:00+00:00
# ❌ No opportunity at 2025-06-16 09:09:00+00:00
# ❌ No opportunity at 2025-06-16 09:10:00+00:00
# ❌ No opportunity at 2025-06-16 09:11:00+00:00
# ❌ No opportunity at 2025-06-16 09:12:00+00:00
# ❌ No opportunity at 2025-06-16 09:13:00+00:00
# ❌ No opportunity at 2025-06-16 09:14:00+00:00
# ❌ No opportunity at 2025-06-16 09:15:00+00:00
# ❌ No opportunity at 2025-06-16 09:16:00+00:00
# ❌ No opportunity at 2025-06-16 09:17:00+00:00
# ❌ No opportunity at 2025-06-16 09:18:00+00:00
# ❌ No opportunity at 2025-06-16 09:19:00+00:00
# ❌ No opportunity at 2025-06-16 09:20:00+00:00
# ❌ No opportunity at 2025-06-16 09:21:00+00:00
# ❌ No opportunity at 2025-06-16 09:22:00+00:00
# ❌ No opportunity at 2025-06-16 09:23:00+00:00
# ❌ No opportunity at 2025-06-16 09:24:00+00:00
# ❌ No opportunity at 2025-06-16 09:25:00+00:00
# ❌ No opportunity at 2025-06-16 09:26:00+00:00
# ❌ No opportunity at 2025-06-16 09:27:00+00:00
# ❌ No opportunity at 2025-06-16 09:28:00+00:00
# ❌ No opportunity at 2025-06-16 09:29:00+00:00
# ❌ No opportunity at 2025-06-16 09:30:00+00:00
# ❌ No opportunity at 2025-06-16 09:31:00+00:00
# ❌ No opportunity at 2025-06-16 09:32:00+00:00
# ❌ No opportunity at 2025-06-16 09:33:00+00:00
# ❌ No opportunity at 2025-06-16 09:34:00+00:00
# ❌ No opportunity at 2025-06-16 09:35:00+00:00
# ❌ No opportunity at 2025-06-16 09:36:00+00:00
# ❌ No opportunity at 2025-06-16 09:37:00+00:00
# ❌ No opportunity at 2025-06-16 09:38:00+00:00
# ❌ No opportunity at 2025-06-16 09:39:00+00:00
# ❌ No opportunity at 2025-06-16 09:40:00+00:00
# ❌ No opportunity at 2025-06-16 09:41:00+00:00
# ❌ No opportunity at 2025-06-16 09:42:00+00:00
# ❌ No opportunity at 2025-06-16 09:43:00+00:00
# ❌ No opportunity at 2025-06-16 09:44:00+00:00
# ❌ No opportunity at 2025-06-16 09:45:00+00:00
# ❌ No opportunity at 2025-06-16 09:46:00+00:00
# ❌ No opportunity at 2025-06-16 09:47:00+00:00
# ❌ No opportunity at 2025-06-16 09:48:00+00:00
#
# 📈 Summary of Monthly Arbitrage Opportunities:
# None found.

# %%
# Import libraries
import pandas as pd
import numpy as np
from itertools import permutations
from oandapyV20 import API
from oandapyV20.endpoints.instruments import InstrumentsCandles

# ===== YOUR CREDENTIALS =====
ACCESS_TOKEN = "32a7ce5d62167ef2dda800802386d48a-496bae9b01506113e0a75dbac8e7a693"

# 1. Function to fetch historical data for one instrument
def fetch_forex_data(instrument="EUR_USD", granularity="D", count=5000):
    client = API(access_token=ACCESS_TOKEN, environment="practice")
    params = {"granularity": granularity, "count": count}
    r = InstrumentsCandles(instrument=instrument, params=params)

    try:
        client.request(r)
    except Exception as e:
        raise ConnectionError(f"Failed to fetch data for {instrument}: {e}")

    data = []
    for candle in r.response['candles']:
        data.append({
            'datetime': candle['time'],
            'close': float(candle['mid']['c'])
        })

    df = pd.DataFrame(data)
    df['datetime'] = pd.to_datetime(df['datetime'])
    df.set_index('datetime', inplace=True)
    return df[['close']].rename(columns={'close': instrument})

# 2. Generate all possible triangular triplets from a list of currencies
def generate_all_triangles(currencies):
    # Avoid repeating same triplet in different orders
    seen = set()
    triangles = []

    for c1, c2, c3 in permutations(currencies, 3):
        key = tuple(sorted([c1, c2, c3]))
        if key not in seen:
            seen.add(key)
            triangles.append([c1, c2, c3])
    return triangles

# 3. Detect arbitrage opportunity at a single timestamp
def detect_opportunity(triangle, row):
    c1, c2, c3 = triangle
    p1 = f"{c1}_{c2}"
    p2 = f"{c2}_{c3}"
    p3 = f"{c3}_{c1}"

    try:
        val = 1.0
        val *= row[p1]
        val *= row[p2]
        val *= row[p3]

        profit = val - 1.0
        return profit
    except KeyError:
        return None

# 4. Main backtest function
def run_full_triangular_arbitrage(pairs, granularities=["M1", "W", "D"], count=5000):
    results = []

    print("📊 Fetching data for:", pairs)
    dfs = [fetch_forex_data(pair, granularity="D", count=count) for pair in pairs]
    merged = pd.concat(dfs, axis=1).dropna().sort_index()

    # Extract unique base currencies
    currencies = set()
    for pair in pairs:
        parts = pair.split("_")
        currencies.update(parts)

    triangles = generate_all_triangles(list(currencies))
    print(f"\n🔄 Testing {len(triangles)} possible triangles...")

    for idx, row in merged.iterrows():
        for triangle in triangles:
            profit = detect_opportunity(triangle, row)
            if profit is not None and profit > 0.0001:
                print(f"✅ Opportunity at {idx} | Triangle: {triangle} | Profit: {profit*100:.4f}%")
                results.append({
                    "timestamp": idx,
                    "triangle": str(triangle),
                    "profit_percent": round(profit * 100, 4),
                    "granularity": "D"
                })

    result_df = pd.DataFrame(results)
    print("\n📈 Summary of Found Opportunities:")
    if not result_df.empty:
        print(result_df.to_string(index=False))
    else:
        print("❌ No arbitrage opportunities found.")
    return result_df

# ===== RUN FULL BACKTEST =====
if __name__ == "__main__":
    # List of forex pairs to analyze
    forex_pairs = [
        "EUR_USD", "GBP_USD", "GBP_CHF",
        "AUD_USD", "NZD_USD",
        "USD_JPY", "EUR_JPY"
    ]

    # Run full analysis
    arbitrage_results = run_full_triangular_arbitrage(
        pairs=forex_pairs,
        granularities=["M1", "W", "D"],  # You can add H4, H1 later
        count=5000
    )
# Out:
# 📊 Fetching data for: ['EUR_USD', 'GBP_USD', 'GBP_CHF', 'AUD_USD', 'NZD_USD', 'USD_JPY', 'EUR_JPY']
#
# 🔄 Testing 35 possible triangles...
#
# 📈 Summary of Found Opportunities:
# ❌ No arbitrage opportunities found.

# %%
import ccxt
import pandas as pd
import numpy as np

# 1. Connect to Binance
exchange = ccxt.binance()

# 2. Define triangle
triangle = ['BTC', 'USDT', 'ETH']

# 3. Get price for a pair
def get_price(symbol):
    ticker = exchange.fetch_ticker(symbol)
    return ticker['last']

# 4. Detect arbitrage opportunity
def detect_crypto_arbitrage(triangle):
    c1, c2, c3 = triangle

    p1 = f"{c1}/{c2}"   # e.g., BTC/USDT
    p2 = f"{c2}/{c3}"   # e.g., USDT/ETH
    p3 = f"{c3}/{c1}"   # e.g., ETH/BTC

    try:
        price1 = get_price(p1)
        price2 = get_price(p2)
        price3 = get_price(p3)

        # Start with 1 of asset c1
        amount = 1.0
        amount = amount * price1  # c1 -> c2
        amount = amount * price2  # c2 -> c3
        amount = amount * price3  # c3 -> c1

        profit = amount - 1.0

        print(f"\n💱 Triangle: {triangle}")
        print(f"📊 Prices: {p1}={price1:.8f}, {p2}={price2:.8f}, {p3}={price3:.8f}")
        if profit > 0:
            print(f"✅ Profit: {profit*100:.4f}%")
        else:
            print(f"❌ Loss or no profit: {profit*100:.4f}%")

        return {
            "triangle": str(triangle),
            "profit_percent": round(profit * 100, 4),
            "prices": f"{p1}:{price1}, {p2}:{price2}, {p3}:{price3}"
        }

    except Exception as e:
        print("⚠️ Error fetching data:", e)
        return None

# ===== RUN SCAN =====
if __name__ == "__main__":
    print("🔍 Scanning for crypto triangular arbitrage opportunities...\n")
    result = detect_crypto_arbitrage(["BTC", "USDT", "ETH"])

    print("\n📈 Final Result:")
    if result and result["profit_percent"] > 0:
        print("✅ Opportunity Found!")
        print(result)
    else:
        print("❌ No arbitrage opportunity found at the moment.")
# Out:
# 🔍 Scanning for crypto triangular arbitrage opportunities...
#
# ⚠️ Error fetching data: binance does not have market symbol USDT/ETH
#
# 📈 Final Result:
# ❌ No arbitrage opportunity found at the moment.

# %%
import ccxt
import pandas as pd
import numpy as np

# 1. Connect to Binance
exchange = ccxt.binance()

# 2. Define triangle and valid pairs
triangle = ['BTC', 'USDT', 'ETH']
valid_pairs = {
    'BTC_USDT': 'BTC/USDT',
    'ETH_USDT': 'ETH/USDT',
    'ETH_BTC': 'ETH/BTC'
}

# 3. Get price for a pair
def get_price(symbol):
    ticker = exchange.fetch_ticker(symbol)
    return ticker['last']

# 4. Detect arbitrage opportunity
def detect_crypto_arbitrage(triangle):
    c1, c2, c3 = triangle

    p1 = valid_pairs['BTC_USDT']   # BTC -> USDT
    p2 = valid_pairs['ETH_USDT']   # USDT -> ETH (buy ETH with USDT)
    p3 = valid_pairs['ETH_BTC']    # ETH -> BTC

    try:
        price1 = get_price(p1)     # How much USDT per BTC
        price2 = get_price(p2)     # How much ETH per USDT
        price3 = get_price(p3)     # How much BTC per ETH

        # Start with 1 BTC
        amount = 1.0
        amount *= price1           # BTC -> USDT
        amount *= price2           # USDT -> ETH
        amount *= price3           # ETH -> BTC

        profit = amount - 1.0

        print(f"\n💱 Triangle: {triangle}")
        print(f"📊 Prices: {p1}={price1:.8f}, {p2}={price2:.8f}, {p3}={price3:.8f}")
        if profit > 0:
            print(f"✅ Profit: {profit*100:.4f}%")
        else:
            print(f"❌ Loss or no profit: {profit*100:.4f}%")

        return {
            "timestamp": pd.Timestamp.now(),
            "triangle": str(triangle),
            "profit_percent": round(profit * 100, 4),
            "prices": f"{p1}:{price1}, {p2}:{price2}, {p3}:{price3}"
        }

    except Exception as e:
        print("⚠️ Error fetching data:", e)
        return None

# ===== RUN SCAN =====
if __name__ == "__main__":
    print("🔍 Scanning for crypto triangular arbitrage opportunities...\n")
    result = detect_crypto_arbitrage(triangle)

    print("\n📈 Final Result:")
    if result and result["profit_percent"] > 0:
        print("✅ Opportunity Found!")
        print(result)
    else:
        print("❌ No arbitrage opportunity found at the moment.")
# Out:
# 🔍 Scanning for crypto triangular arbitrage opportunities...
#
#
# 💱 Triangle: ['BTC', 'USDT', 'ETH']
# 📊 Prices: BTC/USDT=106734.62000000, ETH/USDT=2612.89000000, ETH/BTC=0.02448000
# ✅ Profit: 682712390.4244%
#
# 📈 Final Result:
# ✅ Opportunity Found!
# {'timestamp': Timestamp('2025-06-16 12:00:35.198873'), 'triangle': "['BTC', 'USDT', 'ETH']", 'profit_percent': 682712390.4244, 'prices': 'BTC/USDT:106734.62, ETH/USDT:2612.89, ETH/BTC:0.02448'}

# %%
import ccxt

# 1. Connect to Binance
exchange = ccxt.binance()

# 2. Define triangle
triangle = ['BTC', 'USDT', 'ETH']

# 3. Get price for a pair
def get_price(symbol):
    ticker = exchange.fetch_ticker(symbol)
    return ticker['last']

# 4. Detect arbitrage opportunity
def detect_crypto_arbitrage(triangle):
    c1, c2, c3 = triangle

    price_btc_usdt = get_price('BTC/USDT')  # BTC to USDT
    price_eth_usdt = get_price('ETH/USDT')  # ETH to USDT
    price_eth_btc = get_price('ETH/BTC')    # ETH to BTC

    print(f"\n💱 Triangle: {triangle}")
    print(f"📊 Prices: BTC/USDT={price_btc_usdt:.2f}, ETH/USDT={price_eth_usdt:.2f}, ETH/BTC={price_eth_btc:.8f}")

    # Start with 1 BTC
    start_btc = 1.0
    usdt_amount = start_btc * price_btc_usdt  # BTC -> USDT
    eth_amount = usdt_amount / price_eth_usdt  # USDT -> ETH
    final_btc = eth_amount * price_eth_btc     # ETH -> BTC

    profit = final_btc - start_btc

    if profit > 0:
        print(f"✅ Profit: {profit*100:.4f}%")
    else:
        print(f"❌ Loss or no profit: {profit*100:.4f}%")

    return {
        "start_btc": start_btc,
        "final_btc": final_btc,
        "profit_percent": round(profit * 100, 4),
        "prices": f"BTC/USDT:{price_btc_usdt}, ETH/USDT:{price_eth_usdt}, ETH/BTC:{price_eth_btc}"
    }

# ===== RUN SCAN =====
if __name__ == "__main__":
    print("🔍 Scanning for crypto triangular arbitrage opportunities...\n")
    result = detect_crypto_arbitrage(triangle)

    print("\n📈 Final Result:")
    if result and result["profit_percent"] > 0:
        print("✅ Opportunity Found!")
        print(result)
    else:
        print("❌ No arbitrage opportunity found at the moment.")
# Out:
# 🔍 Scanning for crypto triangular arbitrage opportunities...
#
#
# 💱 Triangle: ['BTC', 'USDT', 'ETH']
# 📊 Prices: BTC/USDT=106788.33, ETH/USDT=2611.42, ETH/BTC=0.02445000
# ❌ Loss or no profit: -0.0171%
#
# 📈 Final Result:
# ❌ No arbitrage opportunity found at the moment.

# %%
import ccxt
import time
from itertools import permutations

# ===== CONFIGURATION =====
exchange = ccxt.binance()
coins = ['BTC', 'USDT', 'ETH', 'BNB', 'XRP', 'DOGE', 'ADA']  # Add more if needed
min_profit_threshold = 0.2  # Only show opportunities with at least this % profit

# ===== HELPER FUNCTIONS =====
def get_price(pair):
    try:
        return exchange.fetch_ticker(pair)['last']
    except Exception as e:
        # print(f"⚠️ Error fetching {pair}: {e}")
        return None

def get_valid_pairs(triangle):
    """Returns valid trading pairs for a given triangle if they exist"""
    c1, c2, c3 = triangle

    pair1 = f"{c1}/{c2}"
    pair2 = f"{c2}/{c3}"
    pair3 = f"{c3}/{c1}"

    price1 = get_price(pair1)
    price2 = get_price(pair2)
    price3 = get_price(pair3)

    if None in [price1, price2, price3]:
        return None

    return {
        "pair1": pair1,
        "pair2": pair2,
        "pair3": pair3,
        "price1": price1,
        "price2": price2,
        "price3": price3
    }

def detect_opportunity(triangle):
    prices = get_valid_pairs(triangle)
    if not prices:
        return None

    c1, c2, c3 = triangle
    p1, p2, p3 = prices["pair1"], prices["pair2"], prices["pair3"]
    price1, price2, price3 = prices["price1"], prices["price2"], prices["price3"]

    # Start with 1 of c1
    amount = 1.0
    amount *= price1  # c1 -> c2
    amount *= price2  # c2 -> c3
    amount *= price3  # c3 -> c1

    profit_percent = (amount - 1) * 100

    if profit_percent > min_profit_threshold:
        return {
            "timestamp": pd.Timestamp.now(),
            "triangle": str(triangle),
            "profit_percent": round(profit_percent, 4),
            "prices": f"{p1}:{price1:.8f}, {p2}:{price2:.8f}, {p3}:{price3:.8f}"
        }
    return None

# ===== MAIN SCANNER =====
if __name__ == "__main__":
    print("🔍 Starting multi-crypto triangular arbitrage scanner...\n")
    print(f"Supported coins: {coins}")
    print(f"Minimum profit threshold: {min_profit_threshold}%\n")

    found_any = False

    # Generate all possible 3-coin triangles
    for triangle in permutations(coins, 3):
        result = detect_opportunity(triangle)
        if result:
            print(f"✅ Opportunity Found: {result['triangle']}")
            print(f"📊 Profit: {result['profit_percent']}%")
            print(f"💱 Prices: {result['prices']}\n")
            found_any = True

    if not found_any:
        print("❌ No arbitrage opportunities found at the moment.")
    else:
        print("🎉 Done scanning — check above for profitable triangles.")
# Out:
# 🔍 Starting multi-crypto triangular arbitrage scanner...
#
# Supported coins: ['BTC', 'USDT', 'ETH', 'BNB', 'XRP', 'DOGE', 'ADA']
# Minimum profit threshold: 0.2%
#
# ❌ No arbitrage opportunities found at the moment.

# %%
import ccxt
from itertools import permutations

# ===== CONFIGURATION =====
exchange = ccxt.binance()

# Expanded list of tradable coins
coins = [
    'BTC', 'USDT', 'ETH', 'BNB', 'XRP', 'DOGE', 'ADA',
    'SOL', 'DOT', 'SHIB', 'MATIC', 'LTC', 'LINK', 'ATOM', 'XMR'
]

min_profit_threshold = 0.2  # Only show opportunities above this %

# ===== HELPER FUNCTIONS =====
def get_price(pair):
    try:
        return exchange.fetch_ticker(pair)['last']
    except Exception as e:
        return None

def detect_opportunity(triangle):
    c1, c2, c3 = triangle

    pair1 = f"{c1}/{c2}"
    pair2 = f"{c2}/{c3}"
    pair3 = f"{c3}/{c1}"

    price1 = get_price(pair1)
    price2 = get_price(pair2)
    price3 = get_price(pair3)

    if None in [price1, price2, price3]:
        return None

    # Start with 1 of c1
    amount = 1.0
    amount *= price1  # c1 -> c2
    amount *= price2  # c2 -> c3
    amount *= price3  # c3 -> c1

    profit_percent = (amount - 1) * 100

    if profit_percent > min_profit_threshold:
        return {
            "triangle": str(triangle),
            "profit_percent": round(profit_percent, 4),
            "prices": f"{pair1}:{price1:.8f}, {pair2}:{price2:.8f}, {pair3}:{price3:.8f}"
        }
    return None

# ===== MAIN SCANNER =====
if __name__ == "__main__":
    print("🔍 Starting expanded crypto triangular arbitrage scanner...\n")
    print(f"Supported coins: {coins}")
    print(f"Minimum profit threshold: {min_profit_threshold}%\n")

    found_any = False

    # Generate all possible 3-coin triangles
    for triangle in permutations(coins, 3):
        # Skip if same coin used twice
        if len(set(triangle)) < 3:
            continue

        result = detect_opportunity(triangle)
        if result:
            print(f"✅ Opportunity Found: {result['triangle']}")
            print(f"📊 Profit: {result['profit_percent']}%")
            print(f"💱 Prices: {result['prices']}\n")
            found_any = True

    if not found_any:
        print("❌ No arbitrage opportunities found at the moment.")
    else:
        print("🎉 Done scanning — check above for profitable triangles.")
# Out:
# 🔍 Starting expanded crypto triangular arbitrage scanner...
#
# Supported coins: ['BTC', 'USDT', 'ETH', 'BNB', 'XRP', 'DOGE', 'ADA', 'SOL', 'DOT', 'SHIB', 'MATIC', 'LTC', 'LINK', 'ATOM', 'XMR']
# Minimum profit threshold: 0.2%
#
# ❌ No arbitrage opportunities found at the moment.
